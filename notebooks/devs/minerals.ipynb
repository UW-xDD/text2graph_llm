# %% [markdown]
# # End-to-end example of using Ask-xDD and text2graph_llm (location extraction)

# %%
import requests
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# Let's say we are interested in critical minerals and their locations.

# %%
# https://www.usgs.gov/news/national-news-release/us-geological-survey-releases-2022-list-critical-minerals

critical_minerals = [
    "aluminium",
    "antimony",
    "arsenic",
    "barite",
    "beryllium",
    "bismuth",
    "cerium",
    "cesium",
    "chromium",
    "cobalt",
    "dysprosium",
    "erbium",
    "europium",
    "fluorspar",
    "gadolinium",
    "gallium",
    "germanium",
    "graphite",
    "hafnium",
    "holmium",
    "indium",
    "iridium",
    "lanthanum",
    "lithium",
    "lutetium",
    "magnesium",
    "manganese",
    "neodymium",
    "nickel",
    "niobium",
    "palladium",
    "platinum",
    "praseodymium",
    "rhodium",
    "rubidium",
    "ruthenium",
    "samarium",
    "scandium",
    "tantalum",
    "tellurium",
    "terbium",
    "thulium",
    "tin",
    "titanium",
    "tungsten",
    "vanadium",
    "ytterbium",
    "yttrium",
    "zinc",
    "zirconium",
]

# %% [markdown]
# ### CriticalMASS minerals

# %%
import requests

response = requests.get("https://macrostrat.org/api/defs/minerals?all")
macrostrat_minerals = [d["mineral"].lower() for d in response.json()["success"]["data"]]

# %%
response.json()["success"]["data"]
# Out:
# [{'mineral_id': 1,
#   'mineral': 'Abelsonite',
#   'mineral_type': '',
#   'formula': 'Ni(C31H32N4)',
#   'formula_tags': 'Ni(C<sub>31</sub>H<sub>32</sub>N<sub>4</sub>)',
#   'url': 'http://www.mindat.org/min-1.html',
#   'hardness_min': 2,
#   'hardness_max': 3,
#   'crystal_form': 'Triclinic',
#   'mineral_color': 'Pink-purple, dark greyish purple, pale purplish red, reddish brown.',
#   'lustre': 'Adamantine, Sub-Metallic'},
#  {'mineral_id': 2,
#   'mineral': 'Abenakiite-(Ce)',
#   'mineral_type': '',
#   'formula': 'Na26Ce6(Si6O18)(PO4)6(CO3)6(SO2)O',
#   'formula_tags': 'Na<sub>26</sub>Ce<sub>6</sub>(Si<sub>6</sub>O<sub>18</sub>)(PO<sub>4</sub>)<sub>6</sub>(CO<sub c',
#   'url': 'http://www.mindat.org/min-2.html',
#   'hardness_min': 4,
#   'hardness_max': 5,
#   'crystal_form': 'Trigonal',
#   'mineral_color': 'Pale brown',
#   'lustre': 'Vitreous'},
#  {'mineral_id': 3,
#   'mineral': 'Abernathyite',
#   'mineral_type': '',
#   'formula': 'K(UO2)(AsO4)·3H2O',
#   'formula_tags': 'K(UO<sub>2</sub>)(AsO<sub>4</sub>) &middot; 3H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-3.html',
#   'hardness_min': 2.5,
#   'hardness_max': 3,
#   'crystal_form': 'Tetragonal',
#   'mineral_color': 'yellow',
#   'lustre': 'Sub-Vitreous, Resinous, Waxy, Greasy'},
#  {'mineral_id': 4,
#   'mineral': 'Abhurite',
#   'mineral_type': '',
#   'formula': 'Sn21Cl16(OH)14O6',
#   'formula_tags': 'Sn<sub>21</sub>Cl<sub>16</sub>(OH)<sub>14</sub>O<sub>6</sub>',
#   'url': 'http://www.mindat.org/min-4.html',
#   'hardness_min': 2,
#   'hardness_max': 2,
#   'crystal_form': 'Trigonal',
#   'mineral_color': 'Colourless',
#   'lustre': None},
#  {'mineral_id': 8,
#   'mineral': 'Absite',
#   'mineral_type': '',
#   'formula': 'Ti7U2ThO20·5H2O or close',
#   'formula_tags': 'Ti<sub>7</sub>U<sub>2</sub>ThO<sub>20</sub> &middot; 5H<sub>2</sub>O or close',
#   'url': 'http://www.mindat.org/min-8.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 9,
#   'mineral': 'Abswurmbachite',
#   'mineral_type': 'nesosilicate',
#   'formula': 'CuMn63+(SiO4)O8',
#   'formula_tags': 'CuMn<sub>6</sub><sup>3+</sup>(SiO<sub>4</sub>)O<sub>8</sub>',
#   'url': 'http://www.mindat.org/min-9.html',
#   'hardness_min': 6.5,
#   'hardness_max': 6.5,
#   'crystal_form': 'Tetragonal',
#   'mineral_color': 'black',
#   'lustre': 'Metallic'},
#  {'mineral_id': 10,
#   'mineral': 'Acanthite',
#   'mineral_type': '',
#   'formula': 'Ag2S',
#   'formula_tags': 'Ag<sub>2</sub>S',
#   'url': 'http://www.mindat.org/min-10.html',
#   'hardness_min': 2,
#   'hardness_max': 2.5,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'lead grey, black',
#   'lustre': 'Metallic'},
#  {'mineral_id': 12,
#   'mineral': 'Acarbodavyne',
#   'mineral_type': '',
#   'formula': '(Na,Ca,K)8(Si6Al6)O24(Cl,SO4)2-3',
#   'formula_tags': '(Na,Ca,K)<sub>8</sub>(Si<sub>6</sub>Al<sub>6</sub>)O<sub>24</sub>(Cl,SO<sub>4</sub>)<sub>2-3</su',
#   'url': 'http://www.mindat.org/min-12.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 13,
#   'mineral': 'Acetamide',
#   'mineral_type': '',
#   'formula': 'CH3CONH2',
#   'formula_tags': 'CH<sub>3</sub>CONH<sub>2</sub>',
#   'url': 'http://www.mindat.org/min-13.html',
#   'hardness_min': 1,
#   'hardness_max': 1.5,
#   'crystal_form': 'Trigonal',
#   'mineral_color': 'Colourless, grey',
#   'lustre': 'Vitreous, Greasy'},
#  {'mineral_id': 14,
#   'mineral': 'Achávalite',
#   'mineral_type': '',
#   'formula': '(Fe,Cu)Se',
#   'formula_tags': '(Fe,Cu)Se',
#   'url': 'http://www.mindat.org/min-14.html',
#   'hardness_min': 2.5,
#   'hardness_max': 2.5,
#   'crystal_form': 'Hexagonal',
#   'mineral_color': 'dark grey',
#   'lustre': 'Metallic'},
#  {'mineral_id': 18,
#   'mineral': 'Actinolite',
#   'mineral_type': 'amphibole',
#   'formula': '☐{Ca2}{Mg4.5-2.5Fe0.5-2.5}(Si8O22)(OH)2',
#   'formula_tags': '☐{Ca<sub>2</sub>}{Mg<sub>4.5-2.5</sub>Fe<sub>0.5-2.5</sub>}(Si<sub>8</sub>O<sub>22</sub>)(OH)<sub>2</sub>',
#   'url': 'http://www.mindat.org/min-18.html',
#   'hardness_min': 5,
#   'hardness_max': 6,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Green, green-black, grey-green, or black',
#   'lustre': 'Vitreous, Silky'},
#  {'mineral_id': 19,
#   'mineral': 'Acuminite',
#   'mineral_type': '',
#   'formula': 'Sr[AlF4(OH)(H2O)]',
#   'formula_tags': 'Sr[AlF<sub>4</sub>(OH)(H<sub>2</sub>O)]',
#   'url': 'http://www.mindat.org/min-19.html',
#   'hardness_min': 3.5,
#   'hardness_max': 3.5,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Colourless, white, becomes yellow on exposure to x-rays',
#   'lustre': 'Vitreous'},
#  {'mineral_id': 21,
#   'mineral': 'Adamite',
#   'mineral_type': '',
#   'formula': 'Zn2(AsO4)(OH)',
#   'formula_tags': 'Zn<sub>2</sub>(AsO<sub>4</sub>)(OH)',
#   'url': 'http://www.mindat.org/min-21.html',
#   'hardness_min': 3.5,
#   'hardness_max': 3.5,
#   'crystal_form': 'Orthorhombic',
#   'mineral_color': 'Ideally white, colourless, frequently pale yellow, honey-yellow, brownish yellow, rose red; blue, pale green to green, may be zoned; bright green (cuprian); bright pink, purple (cobaltian)',
#   'lustre': 'Vitreous, Sub-Vitreous, Waxy, Greasy'},
#  {'mineral_id': 23,
#   'mineral': 'Adelite',
#   'mineral_type': '',
#   'formula': 'CaMg(AsO4)(OH)',
#   'formula_tags': 'CaMg(AsO<sub>4</sub>)(OH)',
#   'url': 'http://www.mindat.org/min-23.html',
#   'hardness_min': 5,
#   'hardness_max': 5,
#   'crystal_form': 'Orthorhombic',
#   'mineral_color': 'Colourless, white, grey, bluish grey, yellowish grey, yellow, pale green, pinkish brown, brown',
#   'lustre': 'Vitreous, Greasy'},
#  {'mineral_id': 27,
#   'mineral': 'Admontite',
#   'mineral_type': '',
#   'formula': 'MgB6O10·7H2O',
#   'formula_tags': 'MgB<sub>6</sub>O<sub>10</sub> &middot; 7H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-27.html',
#   'hardness_min': 2,
#   'hardness_max': 3,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Colourless',
#   'lustre': 'Vitreous'},
#  {'mineral_id': 28,
#   'mineral': 'Adularia',
#   'mineral_type': '',
#   'formula': 'KAlSi3O8',
#   'formula_tags': 'KAlSi<sub>3</sub>O<sub>8</sub>',
#   'url': 'http://www.mindat.org/min-28.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 31,
#   'mineral': 'Aegirine',
#   'mineral_type': 'clinopyroxene',
#   'formula': 'NaFe3+Si2O6',
#   'formula_tags': 'NaFe<sup>3+</sup>Si<sub>2</sub>O<sub>6</sub>',
#   'url': 'http://www.mindat.org/min-31.html',
#   'hardness_min': 6,
#   'hardness_max': 6,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Dark green to greenish black, reddish brown, black',
#   'lustre': 'Vitreous'},
#  {'mineral_id': 32,
#   'mineral': 'Aegirine-augite',
#   'mineral_type': 'clinopyroxene',
#   'formula': '(Na,Ca)(Fe3+,Fe2+,Mg,Al)Si2O6',
#   'formula_tags': '(Na,Ca)(Fe<sup>3+</sup>,Fe<sup>2+</sup>,Mg,Al)Si<sub>2</sub>O<sub>6</sub>',
#   'url': 'http://www.mindat.org/min-32.html',
#   'hardness_min': 6,
#   'hardness_max': 6,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 33,
#   'mineral': 'Aenigmatite',
#   'mineral_type': '',
#   'formula': 'Na2Fe52+Ti(Si6O18)O2',
#   'formula_tags': 'Na<sub>2</sub>Fe<sub>5</sub><sup>2+</sup>Ti(Si<sub>6</sub>O<sub>18</sub>)O<sub>2</sub>',
#   'url': 'http://www.mindat.org/min-33.html',
#   'hardness_min': 5.5,
#   'hardness_max': 6,
#   'crystal_form': 'Triclinic',
#   'mineral_color': 'Velvet-black',
#   'lustre': 'Greasy'},
#  {'mineral_id': 34,
#   'mineral': 'Aerinite',
#   'mineral_type': '',
#   'formula': '(Ca5.1Na0.5)(Fe3+,Al,Fe2+,Mg)4(Al,Mg)6[HSi12O36(OH)12][(CO3)1.2(H2O)12]',
#   'formula_tags': '(Ca<sub>5.1</sub>Na<sub>0.5</sub>)(Fe<sup>3+</sup>,Al,Fe<sup>2+</sup>,Mg)<sub>4</sub>(Al,Mg)<sub',
#   'url': 'http://www.mindat.org/min-34.html',
#   'hardness_min': 3,
#   'hardness_max': 3,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'blue to blue-green',
#   'lustre': None},
#  {'mineral_id': 36,
#   'mineral': 'Aerugite',
#   'mineral_type': '',
#   'formula': 'Ni8.5(AsO4)2As5+O8',
#   'formula_tags': 'Ni<sub>8.5</sub>(AsO<sub>4</sub>)<sub>2</sub>As<sup>5+</sup>O<sub>8</sub>',
#   'url': 'http://www.mindat.org/min-36.html',
#   'hardness_min': 4,
#   'hardness_max': 4,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Dark grass-green, blue-green, pale brown.',
#   'lustre': 'Sub-Adamantine, Sub-Vitreous, Resinous'},
#  {'mineral_id': 37,
#   'mineral': 'Aeschynite-(Ce)',
#   'mineral_type': '',
#   'formula': '(Ce,Ca,Fe,Th)(Ti,Nb)2(O,OH)6',
#   'formula_tags': '(Ce,Ca,Fe,Th)(Ti,Nb)<sub>2</sub>(O,OH)<sub>6</sub>',
#   'url': 'http://www.mindat.org/min-37.html',
#   'hardness_min': 5,
#   'hardness_max': 6,
#   'crystal_form': 'Orthorhombic',
#   'mineral_color': 'Black, brown, light brown to yellow',
#   'lustre': 'Resinous, Waxy, Sub-Metallic'},
#  {'mineral_id': 38,
#   'mineral': 'Aeschynite-(Nd)',
#   'mineral_type': '',
#   'formula': '(Nd,Ce,Ca)(Ti,Nb)2(O,OH)6',
#   'formula_tags': '(Nd,Ce,Ca)(Ti,Nb)<sub>2</sub>(O,OH)<sub>6</sub>',
#   'url': 'http://www.mindat.org/min-38.html',
#   'hardness_min': 5,
#   'hardness_max': 6,
#   'crystal_form': 'Orthorhombic',
#   'mineral_color': 'Dark to pale brown, brownish black',
#   'lustre': 'Adamantine'},
#  {'mineral_id': 39,
#   'mineral': 'Aeschynite-(Y)',
#   'mineral_type': '',
#   'formula': '(Y,Ca,Fe,Th)(Ti,Nb)2(O,OH)6',
#   'formula_tags': '(Y,Ca,Fe,Th)(Ti,Nb)<sub>2</sub>(O,OH)<sub>6</sub>',
#   'url': 'http://www.mindat.org/min-39.html',
#   'hardness_min': 5,
#   'hardness_max': 6,
#   'crystal_form': 'Orthorhombic',
#   'mineral_color': 'Pale yellow, yellow-orange, pale greenish yellow, black, brownishblack',
#   'lustre': 'Resinous, Waxy, Pearly, Sub-Metallic'},
#  {'mineral_id': 41,
#   'mineral': 'Afghanite',
#   'mineral_type': '',
#   'formula': '(Na,K)22Ca10(Si24Al24O96)(SO4)6Cl6',
#   'formula_tags': '(Na,K)<sub>22</sub>Ca<sub>10</sub>(Si<sub>24</sub>Al<sub>24</sub>O<sub>96</sub>)(SO<sub>4</sub>)',
#   'url': 'http://www.mindat.org/min-41.html',
#   'hardness_min': 5.5,
#   'hardness_max': 6,
#   'crystal_form': 'Trigonal',
#   'mineral_color': 'white, light blue, dark blue',
#   'lustre': 'Vitreous'},
#  {'mineral_id': 42,
#   'mineral': 'Afwillite',
#   'mineral_type': 'nesosilicate',
#   'formula': 'Ca3(HSiO4)2·2H2O',
#   'formula_tags': 'Ca<sub>3</sub>(HSiO<sub>4</sub>)<sub>2</sub> &middot; 2H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-42.html',
#   'hardness_min': 3,
#   'hardness_max': 4,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Colourless, white',
#   'lustre': 'Vitreous'},
#  {'mineral_id': 43,
#   'mineral': 'Agardite-(Nd)',
#   'mineral_type': '',
#   'formula': 'NdCu6(AsO4)3(OH)6·3H2O',
#   'formula_tags': 'NdCu<sub>6</sub>(AsO<sub>4</sub>)<sub>3</sub>(OH)<sub>6</sub> &middot; 3H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-43.html',
#   'hardness_min': 3,
#   'hardness_max': 4,
#   'crystal_form': 'Hexagonal',
#   'mineral_color': 'Grass-green, greenish, greenish-blue',
#   'lustre': 'Vitreous'},
#  {'mineral_id': 44,
#   'mineral': 'Agardite-(Y)',
#   'mineral_type': '',
#   'formula': 'YCu6(AsO4)3(OH)6·3H2O',
#   'formula_tags': 'YCu<sub>6</sub>(AsO<sub>4</sub>)<sub>3</sub>(OH)<sub>6</sub> &middot; 3H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-44.html',
#   'hardness_min': 3,
#   'hardness_max': 4,
#   'crystal_form': 'Hexagonal',
#   'mineral_color': 'bluish green to yellow green',
#   'lustre': 'Sub-Vitreous, Resinous, Waxy'},
#  {'mineral_id': 48,
#   'mineral': 'Agardite-(Ce)',
#   'mineral_type': '',
#   'formula': 'CeCu6(AsO4)3(OH)6·3H2O',
#   'formula_tags': 'CeCu<sub>6</sub>(AsO<sub>4</sub>)<sub>3</sub>(OH)<sub>6</sub> &middot; 3H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-48.html',
#   'hardness_min': 3,
#   'hardness_max': 4,
#   'crystal_form': 'Hexagonal',
#   'mineral_color': 'light green, yellowish green',
#   'lustre': 'Sub-Vitreous, Resinous, Silky'},
#  {'mineral_id': 49,
#   'mineral': 'Agardite-(Dy)',
#   'mineral_type': '',
#   'formula': '(Dy,La)Cu6(AsO4)3(OH)6·3H2O',
#   'formula_tags': '(Dy,La)Cu<sub>6</sub>(AsO<sub>4</sub>)<sub>3</sub>(OH)<sub>6</sub> &middot; 3H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-49.html',
#   'hardness_min': 3,
#   'hardness_max': 4,
#   'crystal_form': 'Hexagonal',
#   'mineral_color': 'Grass green',
#   'lustre': 'Vitreous'},
#  {'mineral_id': 50,
#   'mineral': 'Agardite-(La)',
#   'mineral_type': '',
#   'formula': 'LaCu6(AsO4)3(OH)6·3H2O',
#   'formula_tags': 'LaCu<sub>6</sub>(AsO<sub>4</sub>)<sub>3</sub>(OH)<sub>6</sub> &middot; 3H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-50.html',
#   'hardness_min': 3,
#   'hardness_max': 4,
#   'crystal_form': 'Hexagonal',
#   'mineral_color': 'Grass-green to dull green, yellowish green to intense bluish green, rarely nearly colourless.',
#   'lustre': 'Sub-Vitreous, Resinous, Waxy'},
#  {'mineral_id': 51,
#   'mineral': 'Agate',
#   'mineral_type': '',
#   'formula': 'SiO2',
#   'formula_tags': 'SiO<sub>2</sub>',
#   'url': 'http://www.mindat.org/min-51.html',
#   'hardness_min': 6.5,
#   'hardness_max': 7,
#   'crystal_form': '',
#   'mineral_color': 'colorless, gray, red, white, any color due to embedded minerals, multicolored specimen not uncommon',
#   'lustre': 'Waxy, Dull'},
#  {'mineral_id': 57,
#   'mineral': 'Agrellite',
#   'mineral_type': '',
#   'formula': 'NaCa2Si4O10F',
#   'formula_tags': 'NaCa<sub>2</sub>Si<sub>4</sub>O<sub>10</sub>F',
#   'url': 'http://www.mindat.org/min-57.html',
#   'hardness_min': 5.5,
#   'hardness_max': 5.5,
#   'crystal_form': 'Triclinic',
#   'mineral_color': 'White to greyish or greenish white.',
#   'lustre': 'Pearly'},
#  {'mineral_id': 58,
#   'mineral': 'Agrinierite',
#   'mineral_type': '',
#   'formula': 'K2(Ca,Sr)[(UO2)3O3(OH)2]2·5H2O',
#   'formula_tags': 'K<sub>2</sub>(Ca,Sr)[(UO<sub>2</sub>)<sub>3</sub>O<sub>3</sub>(OH)<sub>2</sub>]<sub>2</sub> &mid',
#   'url': 'http://www.mindat.org/min-58.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': 'Orthorhombic',
#   'mineral_color': 'Orange',
#   'lustre': None},
#  {'mineral_id': 59,
#   'mineral': 'Aguilarite',
#   'mineral_type': '',
#   'formula': 'Ag4SeS',
#   'formula_tags': 'Ag<sub>4</sub>SeS',
#   'url': 'http://www.mindat.org/min-59.html',
#   'hardness_min': 2.5,
#   'hardness_max': 2.5,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Bright lead-gray on fresh surfaces',
#   'lustre': 'Metallic'},
#  {'mineral_id': 60,
#   'mineral': 'Aheylite',
#   'mineral_type': '',
#   'formula': '(Fe2+,Zn)Al6(PO4)4(OH)8·4H2O',
#   'formula_tags': '(Fe<sup>2+</sup>,Zn)Al<sub>6</sub>(PO<sub>4</sub>)<sub>4</sub>(OH)<sub>8</sub> &middot; 4H<sub>2',
#   'url': 'http://www.mindat.org/min-60.html',
#   'hardness_min': 5,
#   'hardness_max': 5.5,
#   'crystal_form': 'Triclinic',
#   'mineral_color': 'Very pale blue, pale green, to blue-green',
#   'lustre': 'Sub-Vitreous'},
#  {'mineral_id': 61,
#   'mineral': 'Ahlfeldite',
#   'mineral_type': '',
#   'formula': '(Ni,Co)SeO3·2H2O',
#   'formula_tags': '(Ni,Co)SeO<sub>3</sub> &middot; 2H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-61.html',
#   'hardness_min': 2,
#   'hardness_max': 2.5,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'apple-green, brown, pink, yellowish',
#   'lustre': 'Vitreous'},
#  {'mineral_id': 63,
#   'mineral': 'Aikinite',
#   'mineral_type': '',
#   'formula': 'PbCuBiS3',
#   'formula_tags': 'PbCuBiS<sub>3</sub>',
#   'url': 'http://www.mindat.org/min-63.html',
#   'hardness_min': 2,
#   'hardness_max': 2.5,
#   'crystal_form': 'Orthorhombic',
#   'mineral_color': 'Blackish lead-grey',
#   'lustre': 'Metallic'},
#  {'mineral_id': 66,
#   'mineral': 'Ajoite',
#   'mineral_type': '',
#   'formula': '(K,Na)Cu7AlSi9O24(OH)6·3H2O',
#   'formula_tags': '(K,Na)Cu<sub>7</sub>AlSi<sub>9</sub>O<sub>24</sub>(OH)<sub>6</sub> &middot; 3H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-66.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': 'Triclinic',
#   'mineral_color': 'Bluish green',
#   'lustre': None},
#  {'mineral_id': 67,
#   'mineral': 'Akaganeite',
#   'mineral_type': '',
#   'formula': '(Fe3+,Ni2+)8(OH,O)16Cl1.25·nH2O',
#   'formula_tags': '(Fe<sup>3+</sup>,Ni<sup>2+</sup>)<sub>8</sub>(OH,O)<sub>16</sub>Cl<sub>1.25</sub> &middot; nH<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-67.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Yellowish brown, rusty brown',
#   'lustre': 'Earthy'},
#  {'mineral_id': 68,
#   'mineral': 'Akatoreite',
#   'mineral_type': '',
#   'formula': 'Mn92+Al2Si8O24(OH)8',
#   'formula_tags': 'Mn<sub>9</sub><sup>2+</sup>Al<sub>2</sub>Si<sub>8</sub>O<sub>24</sub>(OH)<sub>8</sub>',
#   'url': 'http://www.mindat.org/min-68.html',
#   'hardness_min': 6,
#   'hardness_max': 6,
#   'crystal_form': 'Triclinic',
#   'mineral_color': 'Yellow-orange to orange-brown',
#   'lustre': 'Vitreous'},
#  {'mineral_id': 69,
#   'mineral': 'Akdalaite',
#   'mineral_type': '',
#   'formula': '4Al2O3·H2O',
#   'formula_tags': '4Al<sub>2</sub>O<sub>3</sub> &middot; H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-69.html',
#   'hardness_min': 7,
#   'hardness_max': 7.5,
#   'crystal_form': 'Hexagonal',
#   'mineral_color': 'White, pale greenish yellow in thin section',
#   'lustre': 'Vitreous'},
#  {'mineral_id': 70,
#   'mineral': 'Åkermanite',
#   'mineral_type': '',
#   'formula': 'Ca2Mg(Si2O7)',
#   'formula_tags': 'Ca<sub>2</sub>Mg(Si<sub>2</sub>O<sub>7</sub>)',
#   'url': 'http://www.mindat.org/min-70.html',
#   'hardness_min': 5,
#   'hardness_max': 6,
#   'crystal_form': 'Tetragonal',
#   'mineral_color': 'Colorless, yellowish gray, green, brown',
#   'lustre': 'Vitreous, Resinous'},
#  {'mineral_id': 71,
#   'mineral': 'Akhtenskite',
#   'mineral_type': '',
#   'formula': 'ε-Mn4+O2',
#   'formula_tags': '&#949;-Mn<sup>4+</sup>O<sub>2</sub>',
#   'url': 'http://www.mindat.org/min-71.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': 'Hexagonal',
#   'mineral_color': 'Light grey to black',
#   'lustre': None},
#  {'mineral_id': 72,
#   'mineral': 'Akrochordite',
#   'mineral_type': '',
#   'formula': '(Mn2+,Mg)5(AsO4)2(OH)4·4H2O',
#   'formula_tags': '(Mn<sup>2+</sup>,Mg)<sub>5</sub>(AsO<sub>4</sub>)<sub>2</sub>(OH)<sub>4</sub> &middot; 4H<sub>2<',
#   'url': 'http://www.mindat.org/min-72.html',
#   'hardness_min': 3.5,
#   'hardness_max': 3.5,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Yellowish red-brown, pale to dark brown, pale pink,',
#   'lustre': 'Sub-Vitreous, Resinous, Dull'},
#  {'mineral_id': 73,
#   'mineral': 'Aksaite',
#   'mineral_type': '',
#   'formula': 'Mg[B6O7(OH)6]·2H2O',
#   'formula_tags': 'Mg[B<sub>6</sub>O<sub>7</sub>(OH)<sub>6</sub>] &middot; 2H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-73.html',
#   'hardness_min': 2.5,
#   'hardness_max': 2.5,
#   'crystal_form': 'Orthorhombic',
#   'mineral_color': 'Colorless, white to pale gray',
#   'lustre': None},
#  {'mineral_id': 74,
#   'mineral': 'Aktashite',
#   'mineral_type': '',
#   'formula': 'Cu6Hg3As4S12',
#   'formula_tags': 'Cu<sub>6</sub>Hg<sub>3</sub>As<sub>4</sub>S<sub>12</sub>',
#   'url': 'http://www.mindat.org/min-74.html',
#   'hardness_min': 3.5,
#   'hardness_max': 3.5,
#   'crystal_form': 'Trigonal',
#   'mineral_color': 'Gray-black',
#   'lustre': 'Metallic'},
#  {'mineral_id': 79,
#   'mineral': 'Alumino-ferro-hornblende',
#   'mineral_type': '',
#   'formula': '☐{Ca2}{Fe42+Al}(AlSi7O22)(OH)2',
#   'formula_tags': '☐{Ca<sub>2</sub>}{Fe<sub>4</sub><sup>2+</sup>Al}(AlSi<sub>7</sub>O<sub>22</sub>)(OH)<sub>2</sub>',
#   'url': 'http://www.mindat.org/min-79.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 83,
#   'mineral': 'Aluminobarroisite',
#   'mineral_type': '',
#   'formula': '☐{CaNa}{Mg3Al2}(AlSi7O22)(OH)2',
#   'formula_tags': '☐{CaNa}{Mg<sub>3</sub>Al<sub>2</sub>}(AlSi<sub>7</sub>O<sub>22</sub>)(OH)<sub>2</sub>',
#   'url': 'http://www.mindat.org/min-83.html',
#   'hardness_min': 5,
#   'hardness_max': 6,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Green, blue',
#   'lustre': None},
#  {'mineral_id': 85,
#   'mineral': 'Alumino-magnesio-hornblende',
#   'mineral_type': '',
#   'formula': '☐{Ca2}{Mg4Al}(AlSi7O22)(OH)2',
#   'formula_tags': '☐{Ca<sub>2</sub>}{Mg<sub>4</sub>Al}(AlSi<sub>7</sub>O<sub>22</sub>)(OH)<sub>2</sub>',
#   'url': 'http://www.mindat.org/min-85.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 87,
#   'mineral': 'Aluminocopiapite',
#   'mineral_type': '',
#   'formula': 'Al2/3Fe43+(SO4)6(OH)2·20H2O',
#   'formula_tags': 'Al<sub>2/3</sub>Fe<sub>4</sub><sup>3+</sup>(SO<sub>4</sub>)<sub>6</sub>(OH)<sub>2<',
#   'url': 'http://www.mindat.org/min-87.html',
#   'hardness_min': 2,
#   'hardness_max': 3,
#   'crystal_form': 'Triclinic',
#   'mineral_color': 'Pale lemon-yellow to deep yellow',
#   'lustre': 'Vitreous'},
#  {'mineral_id': 89,
#   'mineral': 'Alabandite',
#   'mineral_type': '',
#   'formula': 'MnS',
#   'formula_tags': 'MnS',
#   'url': 'http://www.mindat.org/min-89.html',
#   'hardness_min': 3.5,
#   'hardness_max': 4,
#   'crystal_form': 'Isometric',
#   'mineral_color': 'Iron black, brown, greyish black, green; dull brown (tarnished)',
#   'lustre': 'Sub-Metallic'},
#  {'mineral_id': 91,
#   'mineral': 'Alacránite',
#   'mineral_type': '',
#   'formula': 'As8S9',
#   'formula_tags': 'As<sub>8</sub>S<sub>9</sub>',
#   'url': 'http://www.mindat.org/min-91.html',
#   'hardness_min': 1.5,
#   'hardness_max': 1.5,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Orange to pale gray with rose-yellow internal reflections',
#   'lustre': 'Vitreous, Resinous, Greasy'},
#  {'mineral_id': 92,
#   'mineral': 'Alaite',
#   'mineral_type': '',
#   'formula': 'V2O5·H2O',
#   'formula_tags': 'V<sub>2</sub>O<sub>5</sub> &middot; H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-92.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': 'Dark blood-red',
#   'lustre': None},
#  {'mineral_id': 93,
#   'mineral': 'Alamosite',
#   'mineral_type': '',
#   'formula': 'PbSiO3',
#   'formula_tags': 'PbSiO3',
#   'url': 'http://www.mindat.org/min-93.html',
#   'hardness_min': 4.5,
#   'hardness_max': 4.5,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Colorless to white, cream, or light gray',
#   'lustre': 'Adamantine'},
#  {'mineral_id': 94,
#   'mineral': 'Alarsite',
#   'mineral_type': '',
#   'formula': 'AlAsO4',
#   'formula_tags': 'AlAsO<sub>4</sub>',
#   'url': 'http://www.mindat.org/min-94.html',
#   'hardness_min': 5,
#   'hardness_max': 5.5,
#   'crystal_form': 'Trigonal',
#   'mineral_color': 'Colorless, with pale tints of yellow, green, blue due to inclusions',
#   'lustre': 'Vitreous'},
#  {'mineral_id': 96,
#   'mineral': 'Albite',
#   'mineral_type': 'feldspar',
#   'formula': 'Na(AlSi3O8)',
#   'formula_tags': 'Na(AlSi<sub>3</sub>O<sub>8</sub>)',
#   'url': 'http://www.mindat.org/min-96.html',
#   'hardness_min': 6,
#   'hardness_max': 6.5,
#   'crystal_form': 'Triclinic',
#   'mineral_color': 'White to grey, bluish, greenish, reddish',
#   'lustre': 'Vitreous'},
#  {'mineral_id': 97,
#   'mineral': 'Albrechtschraufite',
#   'mineral_type': '',
#   'formula': 'Ca4Mg(UO2)2(CO3)6F2·17-18H2O',
#   'formula_tags': 'Ca<sub>4</sub>Mg(UO<sub>2</sub>)<sub>2</sub>(CO<sub>3</sub>)<sub>6</sub>F<sub>2</sub> &middot; 1',
#   'url': 'http://www.mindat.org/min-97.html',
#   'hardness_min': 2,
#   'hardness_max': 3,
#   'crystal_form': 'Triclinic',
#   'mineral_color': 'Yellow-green',
#   'lustre': 'Vitreous'},
#  {'mineral_id': 101,
#   'mineral': 'Aldanite',
#   'mineral_type': '',
#   'formula': '(Th,Pb)O2 ?',
#   'formula_tags': '(Th,Pb)O<sub>2</sub> ?',
#   'url': 'http://www.mindat.org/min-101.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 103,
#   'mineral': 'Albrittonite',
#   'mineral_type': '',
#   'formula': 'CoCl2·6H2O',
#   'formula_tags': 'CoCl<sub>2</sub> &middot; 6H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-103.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': 'Purple',
#   'lustre': None},
#  {'mineral_id': 104,
#   'mineral': 'Aldermanite',
#   'mineral_type': '',
#   'formula': 'Mg5Al12(PO4)8(OH)22·32H2O',
#   'formula_tags': 'Mg<sub>5</sub>Al<sub>12</sub>(PO<sub>4</sub>)<sub>8</sub>(OH)<sub>22</sub> &middot; 32H<sub>2</s',
#   'url': 'http://www.mindat.org/min-104.html',
#   'hardness_min': 2,
#   'hardness_max': 2,
#   'crystal_form': 'Orthorhombic',
#   'mineral_color': 'Colorless in transmitted light',
#   'lustre': 'Sub-Vitreous, Pearly'},
#  {'mineral_id': 105,
#   'mineral': 'Aldzhanite',
#   'mineral_type': '',
#   'formula': 'CaMgB2O4Cl·7H2O',
#   'formula_tags': 'CaMgB<sub>2</sub>O<sub>4</sub>Cl &middot; 7H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-105.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 106,
#   'mineral': 'Ferro-taramite',
#   'mineral_type': 'amphibole',
#   'formula': 'Na(CaNa)(Fe32+Al2)(Al2Si6O22)(OH)2',
#   'formula_tags': 'Na(CaNa)(Fe<sub>3</sub><sup>2+</sup>Al<sub>2</sub>)(Al<sub>2</sub>Si<sub>6</sub>O<sub>22</sub>)(OH)<sub>2</sub>',
#   'url': 'http://www.mindat.org/min-106.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Bluish green',
#   'lustre': None},
#  {'mineral_id': 107,
#   'mineral': 'Aluminium',
#   'mineral_type': 'element',
#   'formula': 'Al',
#   'formula_tags': 'Al',
#   'url': 'http://www.mindat.org/min-107.html',
#   'hardness_min': 2,
#   'hardness_max': 3.5,
#   'crystal_form': 'Isometric',
#   'mineral_color': 'Grayish-White',
#   'lustre': 'Metallic'},
#  {'mineral_id': 108,
#   'mineral': 'Aleksite',
#   'mineral_type': '',
#   'formula': 'PbBi2Te2S2',
#   'formula_tags': 'PbBi<sub>2</sub>Te<sub>2</sub>S<sub>2</sub>',
#   'url': 'http://www.mindat.org/min-108.html',
#   'hardness_min': 2.5,
#   'hardness_max': 2.5,
#   'crystal_form': 'Trigonal',
#   'mineral_color': 'In polished section, very pale gray with slight greenish tint',
#   'lustre': 'Metallic'},
#  {'mineral_id': 109,
#   'mineral': 'Alexandrite',
#   'mineral_type': '',
#   'formula': 'BeAl2O4',
#   'formula_tags': 'BeAl<sub>2</sub>O<sub>4</sub>',
#   'url': 'http://www.mindat.org/min-109.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 110,
#   'mineral': 'Alexandrolite',
#   'mineral_type': '',
#   'formula': 'Cr2Al4Si8O25·6H2O',
#   'formula_tags': 'Cr<sub>2</sub>Al<sub>4</sub>Si<sub>8</sub>O<sub>25</sub> &middot; 6H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-110.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 112,
#   'mineral': 'Alforsite',
#   'mineral_type': '',
#   'formula': 'Ba5(PO4)3Cl',
#   'formula_tags': 'Ba<sub>5</sub>(PO<sub>4</sub>)<sub>3</sub>Cl',
#   'url': 'http://www.mindat.org/min-112.html',
#   'hardness_min': 5,
#   'hardness_max': 5,
#   'crystal_form': 'Hexagonal',
#   'mineral_color': 'Colorless',
#   'lustre': 'Vitreous, Sub-Vitreous'},
#  {'mineral_id': 114,
#   'mineral': 'Algodonite',
#   'mineral_type': '',
#   'formula': '(Cu1-xAsx)',
#   'formula_tags': '(Cu<sub>1-x</sub>As<sub>x</sub>)',
#   'url': 'http://www.mindat.org/min-114.html',
#   'hardness_min': 4,
#   'hardness_max': 4,
#   'crystal_form': 'Hexagonal',
#   'mineral_color': 'Steel-gray to silver-white, tarnishes dull on exposure',
#   'lustre': 'Metallic'},
#  {'mineral_id': 115,
#   'mineral': 'Aliettite',
#   'mineral_type': 'chlorite',
#   'formula': 'Ca0.2Mg6((Si,Al)8O20)(OH)4·4H2O',
#   'formula_tags': 'Ca<sub>0.2</sub>Mg<sub>6</sub>((Si,Al)<sub>8</sub>O<sub>20</sub>)(OH)<sub>4</sub> &middot; 4H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-115.html',
#   'hardness_min': 1,
#   'hardness_max': 2,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Colorless, pale yellow or green',
#   'lustre': 'Earthy'},
#  {'mineral_id': 116,
#   'mineral': 'Alipite',
#   'mineral_type': '',
#   'formula': '(Ni,Mg)3Si4O10(OH)2·nH2O',
#   'formula_tags': '(Ni,Mg)<sub>3</sub>Si<sub>4</sub>O<sub>10</sub>(OH)<sub>2</sub> &middot; nH<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-116.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': 'Pale green',
#   'lustre': 'Waxy'},
#  {'mineral_id': 117,
#   'mineral': 'Alisonite',
#   'mineral_type': '',
#   'formula': 'Cu6PbS4',
#   'formula_tags': 'Cu<sub>6</sub>PbS<sub>4</sub>',
#   'url': 'http://www.mindat.org/min-117.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 122,
#   'mineral': 'Allactite',
#   'mineral_type': '',
#   'formula': 'Mn72+(AsO4)2(OH)8',
#   'formula_tags': 'Mn<sub>7</sub><sup>2+</sup>(AsO<sub>4</sub>)<sub>2</sub>(OH)<sub>8</sub>',
#   'url': 'http://www.mindat.org/min-122.html',
#   'hardness_min': 4.5,
#   'hardness_max': 4.5,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Brown, dark to light purplish red, brownish red, colourless to white',
#   'lustre': 'Vitreous, Greasy'},
#  {'mineral_id': 125,
#   'mineral': 'Allanite-(Ce)',
#   'mineral_type': '',
#   'formula': '{CaCe}{Al2Fe2+}(Si2O7)(SiO4)O(OH)',
#   'formula_tags': '{CaCe}{Al<sub>2</sub>Fe<sup>2+</sup>}(Si<sub>2</sub>O<sub>7</sub>)(SiO<sub>4</sub>)O(OH)',
#   'url': 'http://www.mindat.org/min-125.html',
#   'hardness_min': 5.5,
#   'hardness_max': 6,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Brown to black',
#   'lustre': 'Vitreous, Resinous'},
#  {'mineral_id': 126,
#   'mineral': 'Allanite-(La)',
#   'mineral_type': '',
#   'formula': '{CaLa}{Al2Fe2+}(Si2O7)(SiO4)O(OH)',
#   'formula_tags': '{CaLa}{Al<sub>2</sub>Fe<sup>2+</sup>}(Si<sub>2</sub>O<sub>7</sub>)(SiO<sub>4</sub>)O(OH)',
#   'url': 'http://www.mindat.org/min-126.html',
#   'hardness_min': 6,
#   'hardness_max': 6,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Black, with brownish reflections',
#   'lustre': 'Vitreous'},
#  {'mineral_id': 127,
#   'mineral': 'Allanite-(Y)',
#   'mineral_type': '',
#   'formula': '{CaY}{Al2Fe2+}(Si2O7)(SiO4)O(OH)',
#   'formula_tags': '{CaY}{Al<sub>2</sub>Fe<sup>2+</sup>}(Si<sub>2</sub>O<sub>7</sub>)(SiO<sub>4</sub>)O(OH)',
#   'url': 'http://www.mindat.org/min-127.html',
#   'hardness_min': 5.5,
#   'hardness_max': 6.5,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Black',
#   'lustre': 'Sub-Vitreous, Resinous, Waxy, Greasy'},
#  {'mineral_id': 128,
#   'mineral': 'Allargentum',
#   'mineral_type': '',
#   'formula': '(Ag1-xSbx)',
#   'formula_tags': '(Ag<sub>1-x</sub>Sb<sub>x</sub>)',
#   'url': 'http://www.mindat.org/min-128.html',
#   'hardness_min': 3.5,
#   'hardness_max': 3.5,
#   'crystal_form': 'Hexagonal',
#   'mineral_color': 'Silver',
#   'lustre': 'Metallic'},
#  {'mineral_id': 129,
#   'mineral': 'Alleghanyite',
#   'mineral_type': '',
#   'formula': 'Mn52+(SiO4)2(OH)2',
#   'formula_tags': 'Mn<sub>5</sub><sup>2+</sup>(SiO<sub>4</sub>)<sub>2</sub>(OH)<sub>2</sub>',
#   'url': 'http://www.mindat.org/min-129.html',
#   'hardness_min': 5.5,
#   'hardness_max': 5.5,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Pinkish to reddish brown, deep pink, grayish pink',
#   'lustre': 'Sub-Vitreous, Resinous, Waxy, Dull'},
#  {'mineral_id': 134,
#   'mineral': 'Alloclasite',
#   'mineral_type': '',
#   'formula': 'Co1-xFexAsS',
#   'formula_tags': 'Co<sub>1-x</sub>Fe<sub>x</sub>AsS',
#   'url': 'http://www.mindat.org/min-134.html',
#   'hardness_min': 5,
#   'hardness_max': 5,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Steel gray to silver',
#   'lustre': 'Metallic'},
#  {'mineral_id': 139,
#   'mineral': 'Allophane',
#   'mineral_type': '',
#   'formula': '(Al2O3)(SiO2)1.3-2·2.5-3H2O',
#   'formula_tags': '(Al<sub>2</sub>O<sub>3</sub>)(SiO<sub>2</sub>)<sub>1.3-2</sub> &middot; 2.5-3H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-139.html',
#   'hardness_min': 3,
#   'hardness_max': 3,
#   'crystal_form': 'Amorphous',
#   'mineral_color': 'White, pale blue to sky-blue, green, brown',
#   'lustre': 'Waxy'},
#  {'mineral_id': 140,
#   'mineral': 'Allophite',
#   'mineral_type': '',
#   'formula': 'Mg8Al4Si5O24·H2O',
#   'formula_tags': 'Mg<sub>8</sub>Al<sub>4</sub>Si<sub>5</sub>O<sub>24</sub> &middot; H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-140.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 141,
#   'mineral': 'Alluaivite',
#   'mineral_type': 'cyclosilicate',
#   'formula': 'Na19(Ca,Mn)6(Ti,Nb)3Si26O74Cl·2H2O',
#   'formula_tags': 'Na<sub>19</sub>(Ca,Mn)<sub>6</sub>(Ti,Nb)<sub>3</sub>Si<sub>26</sub>O<sub>74</sub>Cl &middot; 2H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-141.html',
#   'hardness_min': 5,
#   'hardness_max': 6,
#   'crystal_form': 'Trigonal',
#   'mineral_color': 'Colorless to weak brownish pink',
#   'lustre': 'Vitreous'},
#  {'mineral_id': 142,
#   'mineral': 'Alluaudite',
#   'mineral_type': '',
#   'formula': '(Na,Ca)Mn2+(Fe3+,Mn2+,Fe2+,Mg)2(PO4)3',
#   'formula_tags': '(Na,Ca)Mn<sup>2+</sup>(Fe<sup>3+</sup>,Mn<sup>2+</sup>,Fe<sup>2+</sup>,Mg)<sub>2</sub>(PO<sub>4<',
#   'url': 'http://www.mindat.org/min-142.html',
#   'hardness_min': 5.5,
#   'hardness_max': 6,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Dirty yellow to brownish yellow, grayish green; surficially dull greenish black, brownish black, black, when altered',
#   'lustre': None},
#  {'mineral_id': 143,
#   'mineral': 'Almbosite',
#   'mineral_type': '',
#   'formula': 'Fe52+Fe43+V46+Si3O27',
#   'formula_tags': 'Fe<sub>5</sub><sup>2+</sup>Fe<sub>4</sub><sup>3+</sup>V<sub>4</sub><sup c',
#   'url': 'http://www.mindat.org/min-143.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': 'grey, blue',
#   'lustre': None},
#  {'mineral_id': 145,
#   'mineral': 'Aloisiite',
#   'mineral_type': '',
#   'formula': 'Na2(Ca,Fe,Mg)5Si2O10·2H2O',
#   'formula_tags': 'Na<sub>2</sub>(Ca,Fe,Mg)<sub>5</sub>Si<sub>2</sub>O<sub>10</sub> &middot; 2H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-145.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 146,
#   'mineral': 'Alstonite',
#   'mineral_type': '',
#   'formula': 'BaCa(CO3)2',
#   'formula_tags': 'BaCa(CO<sub>3</sub>)<sub>2</sub>',
#   'url': 'http://www.mindat.org/min-146.html',
#   'hardness_min': 4,
#   'hardness_max': 4.5,
#   'crystal_form': 'Triclinic',
#   'mineral_color': 'Colourless to snow white, yellow-gray; pale gray, pale cream, pink to pale rose-red',
#   'lustre': 'Vitreous'},
#  {'mineral_id': 147,
#   'mineral': 'Altaite',
#   'mineral_type': '',
#   'formula': 'PbTe',
#   'formula_tags': 'PbTe',
#   'url': 'http://www.mindat.org/min-147.html',
#   'hardness_min': 2,
#   'hardness_max': 3,
#   'crystal_form': 'Isometric',
#   'mineral_color': 'Tin-white with a light yellow tint; yellow-brown, blue (tarnished)',
#   'lustre': 'Metallic'},
#  {'mineral_id': 148,
#   'mineral': 'Althausite',
#   'mineral_type': '',
#   'formula': 'Mg4(PO4)2(OH,O)(F,☐)',
#   'formula_tags': 'Mg<sub>4</sub>(PO<sub>4</sub>)<sub>2</sub>(OH,O)(F,☐)',
#   'url': 'http://www.mindat.org/min-148.html',
#   'hardness_min': 3.5,
#   'hardness_max': 4,
#   'crystal_form': 'Orthorhombic',
#   'mineral_color': 'Pale gray, reddish brown; dark blue, green, black',
#   'lustre': 'Sub-Vitreous, Resinous'},
#  {'mineral_id': 149,
#   'mineral': 'Althupite',
#   'mineral_type': '',
#   'formula': 'AlTh(UO2)7(PO4)4(OH)5O2·15H2O',
#   'formula_tags': 'AlTh(UO<sub>2</sub>)<sub>7</sub>(PO<sub>4</sub>)<sub>4</sub>(OH)<sub>5</sub>O<sub>2</sub> &middo',
#   'url': 'http://www.mindat.org/min-149.html',
#   'hardness_min': 3.5,
#   'hardness_max': 4,
#   'crystal_form': 'Triclinic',
#   'mineral_color': 'Yellow',
#   'lustre': 'Vitreous, Sub-Vitreous'},
#  {'mineral_id': 150,
#   'mineral': 'Altisite',
#   'mineral_type': '',
#   'formula': 'Na3K6Ti2Al2Si8O26Cl3',
#   'formula_tags': 'Na<sub>3</sub>K<sub>6</sub>Ti<sub>2</sub>Al<sub>2</sub>Si<sub>8</sub>O<sub>26</sub>Cl<sub>3</sub>',
#   'url': 'http://www.mindat.org/min-150.html',
#   'hardness_min': 6,
#   'hardness_max': 6,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Colourless',
#   'lustre': 'Vitreous'},
#  {'mineral_id': 152,
#   'mineral': 'Alum',
#   'mineral_type': '',
#   'formula': 'XAl(SO4)2·12H2O',
#   'formula_tags': 'XAl(SO<sub>4</sub>)<sub>2</sub> &middot; 12H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-152.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': None,
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 153,
#   'mineral': 'Aluminian nontronite',
#   'mineral_type': '',
#   'formula': 'Na0.33Fe2.17Al0.83Si3·.17O10(OH)2',
#   'formula_tags': 'Na<sub>0.33</sub>Fe<sub>2.17</sub>Al<sub>0.83</sub>Si<sub>3</sub> &middot; <sub>.17</sub>O<sub>1',
#   'url': 'http://www.mindat.org/min-153.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 154,
#   'mineral': 'Aluminite',
#   'mineral_type': '',
#   'formula': 'Al2(SO4)(OH)4·7H2O',
#   'formula_tags': 'Al<sub>2</sub>(SO<sub>4</sub>)(OH)<sub>4</sub> &middot; 7H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-154.html',
#   'hardness_min': 1,
#   'hardness_max': 2,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'White to yellow, grey; colourless in transmitted light.',
#   'lustre': 'Dull, Earthy'},
#  {'mineral_id': 157,
#   'mineral': 'Alumohydrocalcite',
#   'mineral_type': '',
#   'formula': 'CaAl2(CO3)2(OH)4·4H2O',
#   'formula_tags': 'CaAl<sub>2</sub>(CO<sub>3</sub>)<sub>2</sub>(OH)<sub>4</sub> &middot; 4H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-157.html',
#   'hardness_min': 2.5,
#   'hardness_max': 2.5,
#   'crystal_form': 'Triclinic',
#   'mineral_color': 'Chalky white to pale blue, pale yellow, cream, gray; pale rose or brownish pink to dark violet in chromian varieties',
#   'lustre': None},
#  {'mineral_id': 158,
#   'mineral': 'Pharmacoalumite',
#   'mineral_type': '',
#   'formula': 'KAl4(AsO4)3(OH)4·6.5H2O',
#   'formula_tags': 'KAl<sub>4</sub>(AsO<sub>4</sub>)<sub>3</sub>(OH)<sub>4</sub> &middot; 6.5H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-158.html',
#   'hardness_min': 2.5,
#   'hardness_max': 2.5,
#   'crystal_form': 'Isometric',
#   'mineral_color': 'White, pale yellow',
#   'lustre': 'Sub-Vitreous, Waxy, Dull'},
#  {'mineral_id': 159,
#   'mineral': 'Alumotantite',
#   'mineral_type': '',
#   'formula': 'AlTaO4',
#   'formula_tags': 'AlTaO<sub>4</sub>',
#   'url': 'http://www.mindat.org/min-159.html',
#   'hardness_min': 7.5,
#   'hardness_max': 7.5,
#   'crystal_form': 'Orthorhombic',
#   'mineral_color': 'Colourless to white',
#   'lustre': 'Adamantine, Greasy'},
#  {'mineral_id': 161,
#   'mineral': 'Alunite',
#   'mineral_type': '',
#   'formula': 'KAl3(SO4)2(OH)6',
#   'formula_tags': 'KAl<sub>3</sub>(SO<sub>4</sub>)<sub>2</sub>(OH)<sub>6</sub>',
#   'url': 'http://www.mindat.org/min-161.html',
#   'hardness_min': 3.5,
#   'hardness_max': 4,
#   'crystal_form': 'Trigonal',
#   'mineral_color': 'white, pale shades of gray, yellow, red, to reddish brown',
#   'lustre': 'Vitreous, Pearly'},
#  {'mineral_id': 162,
#   'mineral': 'Alunogen',
#   'mineral_type': '',
#   'formula': 'Al2(SO4)3·17H2O',
#   'formula_tags': 'Al<sub>2</sub>(SO<sub>4</sub>)<sub>3</sub> &middot; 17H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-162.html',
#   'hardness_min': 1.5,
#   'hardness_max': 2,
#   'crystal_form': 'Triclinic',
#   'mineral_color': 'Colorless in crystals, aggregates white, or pale yellow or red from impurities.',
#   'lustre': 'Vitreous, Silky'},
#  {'mineral_id': 163,
#   'mineral': 'Alurgite',
#   'mineral_type': '',
#   'formula': 'K2(Mg,Al)4-5(Al,Si)8O20(OH)4',
#   'formula_tags': 'K<sub>2</sub>(Mg,Al)<sub>4-5</sub>(Al,Si)<sub>8</sub>O<sub>20</sub>(OH)<sub>4</sub>',
#   'url': 'http://www.mindat.org/min-163.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': 'Purple',
#   'lustre': None},
#  {'mineral_id': 165,
#   'mineral': 'Alvanite',
#   'mineral_type': '',
#   'formula': '(Zn,Ni)Al4(V5+O3)2(OH)12·2H2O',
#   'formula_tags': '(Zn,Ni)Al<sub>4</sub>(V<sup>5+</sup>O<sub>3</sub>)<sub>2</sub>(OH)<sub>12</sub> &middot; 2H<sub>',
#   'url': 'http://www.mindat.org/min-165.html',
#   'hardness_min': 3,
#   'hardness_max': 3.5,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Pale bluish green to bluish black.',
#   'lustre': 'Vitreous, Pearly'},
#  {'mineral_id': 168,
#   'mineral': 'Ammonium-Kainite',
#   'mineral_type': '',
#   'formula': 'NH4MgSO4l·3H2O',
#   'formula_tags': 'NH<sub>4</sub>MgSO<sub>4</sub>l &middot; 3H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-168.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 169,
#   'mineral': 'Ammonium-Bromcarnallite',
#   'mineral_type': '',
#   'formula': 'NH4MgBr3·6H2O',
#   'formula_tags': 'NH<sub>4</sub>MgBr<sub>3</sub> &middot; 6H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-169.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 170,
#   'mineral': 'Ammonium-Leucite',
#   'mineral_type': '',
#   'formula': 'NH4AlSi2O6',
#   'formula_tags': 'NH<sub>4</sub>AlSi<sub>2</sub>O<sub>6</sub>',
#   'url': 'http://www.mindat.org/min-170.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 171,
#   'mineral': 'Ammonium-Thomsonite',
#   'mineral_type': '',
#   'formula': '(Na,NH4)Ca2[Al5Si5O20]·6H2O',
#   'formula_tags': '(Na,NH<sub>4</sub>)Ca<sub>2</sub>[Al<sub>5</sub>Si<sub>5</sub>O<sub>20</sub>] &middot; 6H<sub>2<',
#   'url': 'http://www.mindat.org/min-171.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 173,
#   'mineral': 'Ammonium-Aphthitalite',
#   'mineral_type': '',
#   'formula': 'Na(K,NH4)SO4',
#   'formula_tags': 'Na(K,NH<sub>4</sub>)SO<sub>4</sub>',
#   'url': 'http://www.mindat.org/min-173.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': 'Yellowish-white',
#   'lustre': None},
#  {'mineral_id': 174,
#   'mineral': 'Ammonium-Mesolite',
#   'mineral_type': '',
#   'formula': '(NH4)Ca2Al6Si9O30·8H2O',
#   'formula_tags': '(NH<sub>4</sub>)Ca<sub>2</sub>Al<sub>6</sub>Si<sub>9</sub>O<sub>30</sub> &middot; 8H<sub>2</sub>',
#   'url': 'http://www.mindat.org/min-174.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 175,
#   'mineral': 'Ammonium-Weeksite',
#   'mineral_type': '',
#   'formula': '(NH4)2(UO2)2(Si2O5)3·4H2O',
#   'formula_tags': '(NH<sub>4</sub>)<sub>2</sub>(UO<sub>2</sub>)<sub>2</sub>(Si<sub>2</sub>O<sub>5</sub>)<sub>3</sub> &middot; 4H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-175.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 177,
#   'mineral': 'Ammonium-Laumontite',
#   'mineral_type': '',
#   'formula': '[Ca,(NH4)2]Al2Si4O12·4H2O',
#   'formula_tags': '[Ca,(NH<sub>4</sub>)<sub>2</sub>]Al<sub>2</sub>Si<sub>4</sub>O<sub>12</sub> &middot; 4H<sub>2</s',
#   'url': 'http://www.mindat.org/min-177.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 178,
#   'mineral': 'Ammonium-natrolite',
#   'mineral_type': '',
#   'formula': '(NH4)2Si3O10',
#   'formula_tags': '(NH<sub>4</sub>)<sub>2</sub>Si<sub>3</sub>O<sub>10</sub>',
#   'url': 'http://www.mindat.org/min-178.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 179,
#   'mineral': 'Ammonium-Stilbite',
#   'mineral_type': '',
#   'formula': '(NH4)5Al5Si13O36·14H2O',
#   'formula_tags': '(NH<sub>4</sub>)<sub>5</sub>Al<sub>5</sub>Si<sub>13</sub>O<sub>36</sub> &middot; 14H<sub>2</sub>',
#   'url': 'http://www.mindat.org/min-179.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 180,
#   'mineral': 'Amakinite',
#   'mineral_type': '',
#   'formula': '(Fe2+,Mg)(OH)2',
#   'formula_tags': '(Fe<sup>2+</sup>,Mg)(OH)<sub>2</sub>',
#   'url': 'http://www.mindat.org/min-180.html',
#   'hardness_min': 3.5,
#   'hardness_max': 4,
#   'crystal_form': 'Trigonal',
#   'mineral_color': 'Pale green to yellow-green; rapidly turns brown when exposed to air, due to formation of Fe(OH)3',
#   'lustre': None},
#  {'mineral_id': 181,
#   'mineral': 'Amalgam',
#   'mineral_type': '',
#   'formula': '(Ag,Hg)',
#   'formula_tags': '(Ag,Hg)',
#   'url': 'http://www.mindat.org/min-181.html',
#   'hardness_min': 3,
#   'hardness_max': 3.5,
#   'crystal_form': 'Isometric',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 182,
#   'mineral': 'Amarantite',
#   'mineral_type': '',
#   'formula': 'Fe23+(SO4)2O·7H2O',
#   'formula_tags': 'Fe<sub>2</sub><sup>3+</sup>(SO<sub>4</sub>)<sub>2</sub>O &middot; 7H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-182.html',
#   'hardness_min': 2.5,
#   'hardness_max': 2.5,
#   'crystal_form': 'Triclinic',
#   'mineral_color': 'Amaranth-red to brownish red and red-orange',
#   'lustre': 'Vitreous'},
#  {'mineral_id': 183,
#   'mineral': 'Amarillite',
#   'mineral_type': '',
#   'formula': 'NaFe(SO4)2·6H2O',
#   'formula_tags': 'NaFe(SO<sub>4</sub>)<sub>2</sub> &middot; 6H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-183.html',
#   'hardness_min': 2.5,
#   'hardness_max': 3,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Pale yellow with greenish tint.',
#   'lustre': 'Adamantine, Vitreous'},
#  {'mineral_id': 186,
#   'mineral': 'Ammonium-Cryolite',
#   'mineral_type': '',
#   'formula': '(NH4)3AlF6',
#   'formula_tags': '(NH<sub>4</sub>)<sub>3</sub>AlF<sub>6</sub>',
#   'url': 'http://www.mindat.org/min-186.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 187,
#   'mineral': 'Ammonium-Boltwoodite',
#   'mineral_type': '',
#   'formula': '(NH4)2(UO2)2(SiO3)2·5H2O',
#   'formula_tags': '(NH<sub>4</sub>)<sub>2</sub>(UO<sub>2</sub>)<sub>2</sub>(SiO<sub>3</sub>)<sub>2</sub> &middot; 5',
#   'url': 'http://www.mindat.org/min-187.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 189,
#   'mineral': 'Amblygonite',
#   'mineral_type': '',
#   'formula': 'LiAl(PO4)F',
#   'formula_tags': 'LiAl(PO<sub>4</sub>)F',
#   'url': 'http://www.mindat.org/min-189.html',
#   'hardness_min': 5.5,
#   'hardness_max': 6,
#   'crystal_form': 'Triclinic',
#   'mineral_color': 'Milk-white, yellow, beige, salmon-pink, pale green, light blue, grey; colourless in transmitted light.',
#   'lustre': 'Sub-Vitreous, Resinous, Greasy, Pearly'},
#  {'mineral_id': 191,
#   'mineral': 'Ammonium-Heulandite',
#   'mineral_type': '',
#   'formula': '[(NH4)2Ca]2Al4Si14O3·12H2O',
#   'formula_tags': '[(NH<sub>4</sub>)<sub>2</sub>Ca]<sub>2</sub>Al<sub>4</sub>Si<sub>14</sub>O<sub>3</sub> &middot; ',
#   'url': 'http://www.mindat.org/min-191.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 192,
#   'mineral': 'Ammonium-Chabazite',
#   'mineral_type': '',
#   'formula': '[(NH4)2Ca]Al2Si4O12·6H2O',
#   'formula_tags': '[(NH<sub>4</sub>)<sub>2</sub>Ca]Al<sub>2</sub>Si<sub>4</sub>O<sub>12</sub> &middot; 6H<sub>2</su',
#   'url': 'http://www.mindat.org/min-192.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 193,
#   'mineral': 'Ammonium-Carnallite',
#   'mineral_type': '',
#   'formula': 'NH4MgCl3·6H2O',
#   'formula_tags': 'NH<sub>4</sub>MgCl<sub>3</sub> &middot; 6H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-193.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 194,
#   'mineral': 'Ammonium-Uranospinite',
#   'mineral_type': '',
#   'formula': 'NH4UO2AsO4·4H2O',
#   'formula_tags': 'NH<sub>4</sub>UO<sub>2</sub>AsO<sub>4</sub> &middot; 4H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-194.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': 'Tetragonal',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 195,
#   'mineral': 'Ameghinite',
#   'mineral_type': '',
#   'formula': 'Na(H4B3O7)',
#   'formula_tags': 'Na(H<sub>4</sub>B<sub>3</sub>O<sub>7</sub>)',
#   'url': 'http://www.mindat.org/min-195.html',
#   'hardness_min': 2,
#   'hardness_max': 3,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Colourless',
#   'lustre': 'Vitreous'},
#  {'mineral_id': 197,
#   'mineral': 'Amesite',
#   'mineral_type': 'serpentine',
#   'formula': 'Mg2Al(AlSiO5)(OH)4',
#   'formula_tags': 'Mg<sub>2</sub>Al(AlSiO<sub>5</sub>)(OH)<sub>4</sub>',
# ...
#   'url': 'http://www.mindat.org/min-1276.html',
#   'hardness_min': 2.5,
#   'hardness_max': 2.5,
#   'crystal_form': 'Tetragonal',
#   'mineral_color': 'Blue',
#   'lustre': 'Adamantine'},
#  {'mineral_id': 1278,
#   'mineral': 'Diaclasite',
#   'mineral_type': '',
#   'formula': 'near (Mg,Fe)SiO3·1/4H2O',
#   'formula_tags': 'near (Mg,Fe)SiO<sub>3</sub> &middot; 1/4H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-1278.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': '',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 1279,
#   'mineral': 'Diadochite',
#   'mineral_type': '',
#   'formula': 'Fe23+(PO4)(SO4)(OH)·5H2O',
#   'formula_tags': 'Fe<sub>2</sub><sup>3+</sup>(PO<sub>4</sub>)(SO<sub>4</sub>)(OH) &middot; 5H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-1279.html',
#   'hardness_min': 3,
#   'hardness_max': 4,
#   'crystal_form': 'Amorphous',
#   'mineral_color': 'Yellow to greenish-yellow or brown, reddish brown, light green, light yellow; pale yellow to yellowish brown in transmitted light.',
#   'lustre': 'Resinous, Waxy, Greasy, Dull, Earthy'},
#  {'mineral_id': 1282,
#   'mineral': 'Diamond',
#   'mineral_type': '',
#   'formula': 'C',
#   'formula_tags': 'C',
#   'url': 'http://www.mindat.org/min-1282.html',
#   'hardness_min': 10,
#   'hardness_max': 10,
#   'crystal_form': 'Isometric',
#   'mineral_color': 'Colourless, yellowish to yellow, brown, black, blue, green or red, pink, champagne-tan, cognac-brown, lilac (very rare)',
#   'lustre': 'Adamantine, Greasy'},
#  {'mineral_id': 1283,
#   'mineral': 'Diaoyudaoite',
#   'mineral_type': '',
#   'formula': 'NaAl11O17',
#   'formula_tags': 'NaAl<sub>11</sub>O<sub>17</sub>',
#   'url': 'http://www.mindat.org/min-1283.html',
#   'hardness_min': 7.5,
#   'hardness_max': 8,
#   'crystal_form': 'Hexagonal',
#   'mineral_color': 'Colourless, light green',
#   'lustre': 'Vitreous'},
#  {'mineral_id': 1284,
#   'mineral': 'Diaphorite',
#   'mineral_type': '',
#   'formula': 'Ag3Pb2Sb3S8',
#   'formula_tags': 'Ag<sub>3</sub>Pb<sub>2</sub>Sb<sub>3</sub>S<sub>8</sub>',
#   'url': 'http://www.mindat.org/min-1284.html',
#   'hardness_min': 2.5,
#   'hardness_max': 3,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Steel grey to Black',
#   'lustre': 'Metallic'},
#  {'mineral_id': 1285,
#   'mineral': 'Diaspore',
#   'mineral_type': '',
#   'formula': 'AlO(OH)',
#   'formula_tags': 'AlO(OH)',
#   'url': 'http://www.mindat.org/min-1285.html',
#   'hardness_min': 6.5,
#   'hardness_max': 7,
#   'crystal_form': 'Orthorhombic',
#   'mineral_color': 'white, brown, colourless, pale yellow, greyish, greenish grey, lilac, pinkish',
#   'lustre': 'Vitreous, Pearly'},
#  {'mineral_id': 1286,
#   'mineral': 'Dickinsonite-(KMnNa)',
#   'mineral_type': '',
#   'formula': '{KNa}{Mn2+}{Ca}{Na3}{Mn132+}{Al}(PO4)12(OH)2',
#   'formula_tags': '{KNa}{Mn<sup>2+</sup>&#9723;}{Ca}{Na<sub>3</sub>}{Mn<sub>13</sub><sup>2+</sup>}{Al}(PO<sub>4</sub>)<s',
#   'url': 'http://www.mindat.org/min-1286.html',
#   'hardness_min': 3.5,
#   'hardness_max': 4,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Green shades to dark green, yellowish green, brownish green; green in transmitted light.',
#   'lustre': 'Vitreous, Pearly'},
#  {'mineral_id': 1287,
#   'mineral': 'Dickite',
#   'mineral_type': 'kaolinite',
#   'formula': 'Al2(Si2O5)(OH)4',
#   'formula_tags': 'Al<sub>2</sub>(Si<sub>2</sub>O<sub>5</sub>)(OH)<sub>4</sub>',
#   'url': 'http://www.mindat.org/min-1287.html',
#   'hardness_min': 2,
#   'hardness_max': 2.5,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'White, or tinted by impurities',
#   'lustre': None},
#  {'mineral_id': 1289,
#   'mineral': 'Dietrichite',
#   'mineral_type': '',
#   'formula': '(Zn,Fe2+,Mn2+)Al2(SO4)4·22H2O',
#   'formula_tags': '(Zn,Fe<sup>2+</sup>,Mn<sup>2+</sup>)Al<sub>2</sub>(SO<sub>4</sub>)<sub>4</sub> &middot; 22H<sub>',
#   'url': 'http://www.mindat.org/min-1289.html',
#   'hardness_min': 2,
#   'hardness_max': 2,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Brownish yellow; off-white; colourless in transmitted light.',
#   'lustre': 'Silky'},
#  {'mineral_id': 1290,
#   'mineral': 'Dietzeite',
#   'mineral_type': '',
#   'formula': 'Ca2(IO3)2(CrO4)·H2O',
#   'formula_tags': 'Ca<sub>2</sub>(IO<sub>3</sub>)<sub>2</sub>(CrO<sub>4</sub>) &middot; H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-1290.html',
#   'hardness_min': 3.5,
#   'hardness_max': 3.5,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Golden yellow',
#   'lustre': None},
#  {'mineral_id': 1291,
#   'mineral': 'Digenite',
#   'mineral_type': '',
#   'formula': 'Cu9S5',
#   'formula_tags': 'Cu<sub>9</sub>S<sub>5</sub>',
#   'url': 'http://www.mindat.org/min-1291.html',
#   'hardness_min': 2.5,
#   'hardness_max': 3,
#   'crystal_form': 'Trigonal',
#   'mineral_color': 'Grey to greyish black, turning bluish on exposure to air',
#   'lustre': 'Metallic'},
#  {'mineral_id': 1292,
#   'mineral': 'Dimorphite',
#   'mineral_type': '',
#   'formula': 'As4S3',
#   'formula_tags': 'As<sub>4</sub>S<sub>3</sub>',
#   'url': 'http://www.mindat.org/min-1292.html',
#   'hardness_min': 1.5,
#   'hardness_max': 1.5,
#   'crystal_form': 'Orthorhombic',
#   'mineral_color': 'orange-yellow',
#   'lustre': 'Adamantine'},
#  {'mineral_id': 1293,
#   'mineral': 'Diomignite',
#   'mineral_type': '',
#   'formula': 'Li2[B4O7]',
#   'formula_tags': 'Li<sub>2</sub>[B<sub>4</sub>O<sub>7</sub>]',
#   'url': 'http://www.mindat.org/min-1293.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': 'Tetragonal',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 1294,
#   'mineral': 'Diopside',
#   'mineral_type': 'clinopyroxene',
#   'formula': 'CaMgSi2O6',
#   'formula_tags': 'CaMgSi<sub>2</sub>O<sub>6</sub>',
#   'url': 'http://www.mindat.org/min-1294.html',
#   'hardness_min': 5.5,
#   'hardness_max': 6.5,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'light to dark green, blue, brown, colourless, snow white, grey',
#   'lustre': 'Vitreous, Dull'},
#  {'mineral_id': 1295,
#   'mineral': 'Dioptase',
#   'mineral_type': 'cyclosilicate',
#   'formula': 'CuSiO3·H2O',
#   'formula_tags': 'CuSiO<sub>3</sub> &middot; H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-1295.html',
#   'hardness_min': 5,
#   'hardness_max': 5,
#   'crystal_form': 'Trigonal',
#   'mineral_color': 'Emerald Green, blue-green',
#   'lustre': 'Vitreous'},
#  {'mineral_id': 1296,
#   'mineral': 'Dissakisite-(Ce)',
#   'mineral_type': '',
#   'formula': '{CaCe}{Al2Mg}(Si2O7)(SiO4)O(OH)',
#   'formula_tags': '{CaCe}{Al<sub>2</sub>Mg}(Si<sub>2</sub>O<sub>7</sub>)(SiO<sub>4</sub>)O(OH)',
#   'url': 'http://www.mindat.org/min-1296.html',
#   'hardness_min': 6.5,
#   'hardness_max': 7,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 1297,
#   'mineral': 'Dittmarite',
#   'mineral_type': '',
#   'formula': '(NH4)Mg(PO4)·H2O',
#   'formula_tags': '(NH<sub>4</sub>)Mg(PO<sub>4</sub>) &middot; H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-1297.html',
#   'hardness_min': 5,
#   'hardness_max': 5,
#   'crystal_form': 'Orthorhombic',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 1298,
#   'mineral': 'Dixenite',
#   'mineral_type': '',
#   'formula': 'CuMn142+Fe2+(SiO4)2(As5+O4)(As3+O3)5(OH)6',
#   'formula_tags': 'CuMn<sub>14</sub><sup>2+</sup>Fe<sup>2+</sup>(SiO<sub>4</sub>)<sub>2</sub>(As<sup>',
#   'url': 'http://www.mindat.org/min-1298.html',
#   'hardness_min': 3,
#   'hardness_max': 4,
#   'crystal_form': 'Trigonal',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 1299,
#   'mineral': 'Djerfisherite',
#   'mineral_type': '',
#   'formula': 'K6(Fe,Cu,Ni)25S26Cl',
#   'formula_tags': 'K<sub>6</sub>(Fe,Cu,Ni)<sub>25</sub>S<sub>26</sub>Cl',
#   'url': 'http://www.mindat.org/min-1299.html',
#   'hardness_min': 3.5,
#   'hardness_max': 3.5,
#   'crystal_form': 'Isometric',
#   'mineral_color': 'Greenish yellow, khaki, to olive drab',
#   'lustre': 'Sub-Metallic'},
#  {'mineral_id': 1300,
#   'mineral': 'Djurleite',
#   'mineral_type': '',
#   'formula': 'Cu31S16',
#   'formula_tags': 'Cu<sub>31</sub>S<sub>16</sub>',
#   'url': 'http://www.mindat.org/min-1300.html',
#   'hardness_min': 2.5,
#   'hardness_max': 3,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Black, gray in reflected light',
#   'lustre': 'Metallic'},
#  {'mineral_id': 1301,
#   'mineral': 'Dmisteinbergite',
#   'mineral_type': 'feldspar',
#   'formula': 'Ca(Al2Si2O8)',
#   'formula_tags': 'Ca(Al<sub>2</sub>Si<sub>2</sub>O<sub>8</sub>)',
#   'url': 'http://www.mindat.org/min-1301.html',
#   'hardness_min': 6,
#   'hardness_max': 6,
#   'crystal_form': 'Hexagonal',
#   'mineral_color': 'colourless',
#   'lustre': 'Pearly'},
#  {'mineral_id': 1302,
#   'mineral': 'Dolerophanite',
#   'mineral_type': '',
#   'formula': 'Cu2(SO4)O',
#   'formula_tags': 'Cu<sub>2</sub>(SO<sub>4</sub>)O',
#   'url': 'http://www.mindat.org/min-1302.html',
#   'hardness_min': 3,
#   'hardness_max': 3,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Dark brown, nearly black; yellow-brown in transmitted light.',
#   'lustre': None},
#  {'mineral_id': 1303,
#   'mineral': 'Dollaseite-(Ce)',
#   'mineral_type': '',
#   'formula': '{CaCe}{MgAlMg}(Si2O7)(SiO4)(OH)F',
#   'formula_tags': '{CaCe}{MgAlMg}(Si<sub>2</sub>O<sub>7</sub>)(SiO<sub>4</sub>)(OH)F',
#   'url': 'http://www.mindat.org/min-1303.html',
#   'hardness_min': 6.5,
#   'hardness_max': 7,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 1304,
#   'mineral': 'Dolomite',
#   'mineral_type': '',
#   'formula': 'CaMg(CO3)2',
#   'formula_tags': 'CaMg(CO<sub>3</sub>)<sub>2</sub>',
#   'url': 'http://www.mindat.org/min-1304.html',
#   'hardness_min': 3.5,
#   'hardness_max': 4,
#   'crystal_form': 'Trigonal',
#   'mineral_color': 'Colourless, white, gray, reddish-white, brownish-white, or pink; colourless in transmitted light',
#   'lustre': 'Vitreous, Sub-Vitreous, Resinous, Waxy, Pearly'},
#  {'mineral_id': 1305,
#   'mineral': 'Doloresite',
#   'mineral_type': '',
#   'formula': 'V34+O4(OH)4',
#   'formula_tags': 'V<sub>3</sub><sup>4+</sup>O<sub>4</sub>(OH)<sub>4</sub>',
#   'url': 'http://www.mindat.org/min-1305.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 1306,
#   'mineral': 'Domeykite',
#   'mineral_type': '',
#   'formula': 'Cu3As',
#   'formula_tags': 'Cu<sub>3</sub>As',
#   'url': 'http://www.mindat.org/min-1306.html',
#   'hardness_min': 3,
#   'hardness_max': 3.5,
#   'crystal_form': 'Isometric',
#   'mineral_color': 'Tin white - steel grey',
#   'lustre': 'Metallic'},
#  {'mineral_id': 1308,
#   'mineral': 'Donharrisite',
#   'mineral_type': '',
#   'formula': 'Ni8Hg3S9',
#   'formula_tags': 'Ni<sub>8</sub>Hg<sub>3</sub>S<sub>9</sub>',
#   'url': 'http://www.mindat.org/min-1308.html',
#   'hardness_min': 2,
#   'hardness_max': 2,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Brown',
#   'lustre': 'Metallic'},
#  {'mineral_id': 1309,
#   'mineral': 'Donnayite-(Y)',
#   'mineral_type': '',
#   'formula': 'NaCaSr3Y(CO3)6·3H2O',
#   'formula_tags': 'NaCaSr<sub>3</sub>Y(CO<sub>3</sub>)<sub>6</sub> &middot; 3H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-1309.html',
#   'hardness_min': 3,
#   'hardness_max': 3,
#   'crystal_form': 'Triclinic',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 1310,
#   'mineral': 'Donpeacorite',
#   'mineral_type': 'orthopyroxene',
#   'formula': '(Mn2+,Mg)Mg[SiO3]2',
#   'formula_tags': '(Mn<sup>2+</sup>,Mg)Mg[SiO<sub>3</sub>]<sub>2</sub>',
#   'url': 'http://www.mindat.org/min-1310.html',
#   'hardness_min': 5,
#   'hardness_max': 6,
#   'crystal_form': 'Orthorhombic',
#   'mineral_color': None,
#   'lustre': None},
#  {'mineral_id': 1311,
#   'mineral': 'Dorallcharite',
#   'mineral_type': '',
#   'formula': 'TlFe33+(SO4)2(OH)6',
#   'formula_tags': 'TlFe<sub>3</sub><sup>3+</sup>(SO<sub>4</sub>)<sub>2</sub>(OH)<sub>6</sub>',
#   'url': 'http://www.mindat.org/min-1311.html',
#   'hardness_min': 3,
#   'hardness_max': 4,
#   'crystal_form': 'Trigonal',
#   'mineral_color': 'Golden yellow',
#   'lustre': 'Earthy'},
#  {'mineral_id': 1312,
#   'mineral': 'Dorfmanite',
#   'mineral_type': '',
#   'formula': 'Na2HPO4·2H2O',
#   'formula_tags': 'Na<sub>2</sub>HPO<sub>4</sub> &middot; 2H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-1312.html',
#   'hardness_min': 1,
#   'hardness_max': 1.5,
#   'crystal_form': 'Orthorhombic',
#   'mineral_color': 'White',
#   'lustre': None},
#  {'mineral_id': 1313,
#   'mineral': 'Dorrite',
#   'mineral_type': '',
#   'formula': 'Ca4(Mg3Fe93+)O4(Si3Al8Fe3+O36)',
#   'formula_tags': 'Ca<sub>4</sub>(Mg<sub>3</sub>Fe<sub>9</sub><sup>3+</sup>)O<sub>4</sub>(Si<sub>3</s',
#   'url': 'http://www.mindat.org/min-1313.html',
#   'hardness_min': 5.5,
#   'hardness_max': 5.5,
#   'crystal_form': 'Triclinic',
#   'mineral_color': 'red-brown, brown-black, dark brown',
#   'lustre': 'Sub-Metallic'},
#  {'mineral_id': 1314,
#   'mineral': 'Douglasite',
#   'mineral_type': '',
#   'formula': 'K2[Fe2+Cl4(OH2)2]',
#   'formula_tags': 'K<sub>2</sub>[Fe<sup>2+</sup>Cl<sub>4</sub>(OH<sub>2</sub>)<sub>2</sub>]',
#   'url': 'http://www.mindat.org/min-1314.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Light green; brownish red on exposure.',
#   'lustre': 'Vitreous'},
#  {'mineral_id': 1315,
#   'mineral': 'Downeyite',
#   'mineral_type': '',
#   'formula': 'SeO2',
#   'formula_tags': 'SeO<sub>2</sub>',
#   'url': 'http://www.mindat.org/min-1315.html',
#   'hardness_min': None,
#   'hardness_max': None,
#   'crystal_form': 'Tetragonal',
#   'mineral_color': 'Colourless (red - included selenium, yelllow - included sulfur)',
#   'lustre': 'Adamantine'},
#  {'mineral_id': 1316,
#   'mineral': 'Doyleite',
#   'mineral_type': '',
#   'formula': 'Al(OH)3',
#   'formula_tags': 'Al(OH)<sub>3</sub>',
#   'url': 'http://www.mindat.org/min-1316.html',
#   'hardness_min': 2.5,
#   'hardness_max': 3,
#   'crystal_form': 'Triclinic',
#   'mineral_color': 'White, creamy-white, bluish-white',
#   'lustre': 'Vitreous'},
#  {'mineral_id': 1317,
#   'mineral': 'Dozyite',
#   'mineral_type': '',
#   'formula': 'Mg7Al2(Al2Si4O15)(OH)12',
#   'formula_tags': 'Mg<sub>7</sub>Al<sub>2</sub>(Al<sub>2</sub>Si<sub>4</sub>O<sub>15</sub>)(OH)<sup></su',
#   'url': 'http://www.mindat.org/min-1317.html',
#   'hardness_min': 2.5,
#   'hardness_max': 2.5,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Colourless',
#   'lustre': None},
#  {'mineral_id': 1318,
#   'mineral': 'Dravite',
#   'mineral_type': '',
#   'formula': 'Na(Mg3)Al6(Si6O18)(BO3)3(OH)3(OH)',
#   'formula_tags': 'Na(Mg<sub>3</sub>)Al<sub>6</sub>(Si<sub>6</sub>O<sub>18</sub>)(BO<sub>3</sub>)<sub>3</sub>(OH)<s',
#   'url': 'http://www.mindat.org/min-1318.html',
#   'hardness_min': 7,
#   'hardness_max': 7,
#   'crystal_form': 'Trigonal',
#   'mineral_color': 'Pale brown to dark-brown to brownish-black, also dark-yellow, blue.',
#   'lustre': 'Vitreous, Resinous'},
#  {'mineral_id': 1319,
#   'mineral': 'Dresserite',
#   'mineral_type': '',
#   'formula': 'BaAl2(CO3)2(OH)4·H2O',
#   'formula_tags': 'BaAl<sub>2</sub>(CO<sub>3</sub>)<sub>2</sub>(OH)<sub>4</sub> &middot; H<sub>2</sub>O',
#   'url': 'http://www.mindat.org/min-1319.html',
#   'hardness_min': 2.5,
#   'hardness_max': 3,
#   'crystal_form': 'Orthorhombic',
#   'mineral_color': 'White',
#   'lustre': 'Vitreous, Silky'},
#  {'mineral_id': 1320,
#   'mineral': 'Dreyerite',
#   'mineral_type': '',
#   'formula': 'Bi(VO4)',
#   'formula_tags': 'Bi(VO<sub>4</sub>)',
#   'url': 'http://www.mindat.org/min-1320.html',
#   'hardness_min': 2,
#   'hardness_max': 3,
#   'crystal_form': 'Tetragonal',
#   'mineral_color': 'Orange-yellow, brownish-yellow',
#   'lustre': 'Adamantine'},
#  {'mineral_id': 1321,
#   'mineral': 'Drugmanite',
#   'mineral_type': '',
#   'formula': 'Pb2(Fe3+,Al)(PO4)(PO3OH)(OH)2',
#   'formula_tags': 'Pb<sub>2</sub>(Fe<sup>3+</sup>,Al)(PO<sub>4</sub>)(PO<sub>3</sub>OH)(OH)<sub>2</sub>',
#   'url': 'http://www.mindat.org/min-1321.html',
#   'hardness_min': 5,
#   'hardness_max': 6,
#   'crystal_form': 'Monoclinic',
#   'mineral_color': 'Pale yellow',
#   'lustre': 'Adamantine'},
#  {'mineral_id': 1322,
#   'mineral': 'Drysdallite',
#   'mineral_type': '',
#   'formula': 'Mo(Se,S)2',
#   'formula_tags': 'Mo(Se,S)<sub>2</sub>',
#   'url': 'http://www.mindat.org/min-1322.html',
#   'hardness_min': 2,
#   'hardness_max': 2,
#   'crystal_form': 'Hexagonal',
#   'mineral_color': 'Grayish black with a brown tint',
#   'lustre': 'Metallic'},
#  ...]

# %%
n_in = 0
n_out = 0
for m in critical_minerals:
    # in macrostrat

    if m in macrostrat_minerals:
        n_in += 1
        print(f"IN macrostrat: {m}")
    else:
        n_out += 1
        print(f"NOT IN macrostrat: {m}")

print(f"IN: {n_in}")
print(f"OUT: {n_out}")
# Out:
# IN macrostrat: aluminium
# IN macrostrat: antimony
# IN macrostrat: arsenic
# NOT IN macrostrat: barite
# NOT IN macrostrat: beryllium
# IN macrostrat: bismuth
# IN macrostrat: cerium
# NOT IN macrostrat: cesium
# IN macrostrat: chromium
# IN macrostrat: cobalt
# NOT IN macrostrat: dysprosium
# NOT IN macrostrat: erbium
# NOT IN macrostrat: europium
# NOT IN macrostrat: fluorspar
# NOT IN macrostrat: gadolinium
# NOT IN macrostrat: gallium
# NOT IN macrostrat: germanium
# IN macrostrat: graphite
# NOT IN macrostrat: hafnium
# NOT IN macrostrat: holmium
# IN macrostrat: indium
# IN macrostrat: iridium
# NOT IN macrostrat: lanthanum
# NOT IN macrostrat: lithium
# NOT IN macrostrat: lutetium
# IN macrostrat: magnesium
# IN macrostrat: manganese
# NOT IN macrostrat: neodymium
# IN macrostrat: nickel
# IN macrostrat: niobium
# IN macrostrat: palladium
# IN macrostrat: platinum
# NOT IN macrostrat: praseodymium
# IN macrostrat: rhodium
# NOT IN macrostrat: rubidium
# IN macrostrat: ruthenium
# NOT IN macrostrat: samarium
# NOT IN macrostrat: scandium
# IN macrostrat: tantalum
# IN macrostrat: tellurium
# NOT IN macrostrat: terbium
# NOT IN macrostrat: thulium
# IN macrostrat: tin
# IN macrostrat: titanium
# IN macrostrat: tungsten
# IN macrostrat: vanadium
# IN macrostrat: ytterbium
# NOT IN macrostrat: yttrium
# IN macrostrat: zinc
# NOT IN macrostrat: zirconium
# IN: 26
# OUT: 24

# %%
print(macrostrat_minerals)
# Out:
# ['abelsonite', 'abenakiite-(ce)', 'abernathyite', 'abhurite', 'absite', 'abswurmbachite', 'acanthite', 'acarbodavyne', 'acetamide', 'achávalite', 'actinolite', 'acuminite', 'adamite', 'adelite', 'admontite', 'adularia', 'aegirine', 'aegirine-augite', 'aenigmatite', 'aerinite', 'aerugite', 'aeschynite-(ce)', 'aeschynite-(nd)', 'aeschynite-(y)', 'afghanite', 'afwillite', 'agardite-(nd)', 'agardite-(y)', 'agardite-(ce)', 'agardite-(dy)', 'agardite-(la)', 'agate', 'agrellite', 'agrinierite', 'aguilarite', 'aheylite', 'ahlfeldite', 'aikinite', 'ajoite', 'akaganeite', 'akatoreite', 'akdalaite', 'åkermanite', 'akhtenskite', 'akrochordite', 'aksaite', 'aktashite', 'alumino-ferro-hornblende', 'aluminobarroisite', 'alumino-magnesio-hornblende', 'aluminocopiapite', 'alabandite', 'alacránite', 'alaite', 'alamosite', 'alarsite', 'albite', 'albrechtschraufite', 'aldanite', 'albrittonite', 'aldermanite', 'aldzhanite', 'ferro-taramite', 'aluminium', 'aleksite', 'alexandrite', 'alexandrolite', 'alforsite', 'algodonite', 'aliettite', 'alipite', 'alisonite', 'allactite', 'allanite-(ce)', 'allanite-(la)', 'allanite-(y)', 'allargentum', 'alleghanyite', 'alloclasite', 'allophane', 'allophite', 'alluaivite', 'alluaudite', 'almbosite', 'aloisiite', 'alstonite', 'altaite', 'althausite', 'althupite', 'altisite', 'alum', 'aluminian nontronite', 'aluminite', 'alumohydrocalcite', 'pharmacoalumite', 'alumotantite', 'alunite', 'alunogen', 'alurgite', 'alvanite', 'ammonium-kainite', 'ammonium-bromcarnallite', 'ammonium-leucite', 'ammonium-thomsonite', 'ammonium-aphthitalite', 'ammonium-mesolite', 'ammonium-weeksite', 'ammonium-laumontite', 'ammonium-natrolite', 'ammonium-stilbite', 'amakinite', 'amalgam', 'amarantite', 'amarillite', 'ammonium-cryolite', 'ammonium-boltwoodite', 'amblygonite', 'ammonium-heulandite', 'ammonium-chabazite', 'ammonium-carnallite', 'ammonium-uranospinite', 'ameghinite', 'amesite', 'amethyst', 'amicite', 'aminoffite', 'ammonioalunite', 'ammonioborite', 'ammoniojarosite', 'ammonioleucite', 'amphibole supergroup', 'amstallite', 'analcime', 'anapaite', 'anatase', 'ancylite-(ce)', 'andalusite', 'anderbergite', 'andersonite', 'andesine', 'andorite', 'andradite', 'andrémeyerite', 'anduoite', 'angelellite', 'anglesite', 'anhydrite', 'anhydrokainite', 'anilite', 'ankangite', 'ankerite', 'annabergite', 'annite', 'bismuthian tetrahedrite', 'anorthite', 'anorthoclase', 'anosovite', 'antarcticite', 'anthoinite', 'anthonyite', 'anthophyllite', 'antigorite', 'antillite', 'antimony', 'antimonial arsenic', 'antimonial silver', 'antimonselite', 'antlerite', 'anyuiite', 'apachite', 'apatelite', 'apatite supergroup', 'aphrosiderite', 'aphthitalite', 'apjohnite', 'aplowite', 'apthonite', 'apuanite', 'aquacreptite (of harada)', 'aquacreptite (of shepard)', 'aquamarine', 'argentojarosite', 'argentopentlandite', 'arsenogoyazite', 'argentocuproauride', 'arsenolite', 'arsenoflorencite-(la)', 'arsenoflorencite-(nd)', 'arsenosulvanite', 'argentodomeykite', 'argentopyrite', 'argentocuprocosalite', 'arsenohauchecornite', 'arsenotellurite', 'arsenopalladinite', 'arsenogorceixite', 'arsenopyrite', 'argentogoongarrite', 'aragonite', 'aragotite', 'aramayoite', 'aravaipaite', 'arsenolamprite', 'argentian lillianite', 'arcanite', 'archerite', 'arctite', 'arctolite', 'arcubisite', 'argentotennantite', 'ardaite', 'ardealite', 'ardennite-(as)', 'arfvedsonite', 'argentoaikinite', 'argentoalgodonite', 'argentocosalite', 'argutite', 'argyrodite', 'argyropyrite', 'arhbarite', 'aristarainite', 'arite', 'arkelite', 'armalcolite', 'armangite', 'armenite', 'armstrongite', 'aromite (of darapsky)', 'arquerite', 'arrhenite', 'arrojadite-(kfe)', 'antimonian gersdorffite', 'arsenargentite', 'arsendescloizite', 'arsenic', 'arseniopleite', 'arseniosiderite', 'arsenmiargyrite', 'arsennickeleisen', 'arsenoclasite', 'arsenocrandallite', 'arsenoflorencite-(ce)', 'arsenschwefel', 'arsenstruvite', 'arsensulfurite', 'arsentsumebite', 'arsenuranospathite', 'arsenuranylite', 'arthurite', 'arti ...

# %% [markdown]
# ### Get sample text from `CriticalMAAS` dataset

# %%
ASK_XDD_APIKEY = os.getenv("ASK_XDD_APIKEY")
ENDPOINT = "http://cosmos0001.chtc.wisc.edu:4502/hybrid"

headers = {"Content-Type": "application/json", "Api-Key": ASK_XDD_APIKEY}
data = {
    "topic": "criticalmaas",
    "question": "Aluminum Mines in USA.",
    "top_k": 10,
    "temperature": 1.0,
}

response = requests.post(ENDPOINT, headers=headers, json=data)
response.json()
# Out:
# [{'paper_id': '557ca80ae138239225f86935',
#   'preprocessor_id': 'haystack_v0.0.2',
#   'doc_type': 'paragraph',
#   'topic_list': ['criticalmaas'],
#   'text_content': 'ALUMINUM, TOTAL RECOVERABLE (UG/L AS AL) ARSENIC, TOTAL RECOVERABLE (UG/L AS AS) BERYLLIUM, TOTAL RECOVERABLE (UG/L AS BE) CADMIUM TOTAL RECOVERABLE (UG/L AS CD) CHROMIUM, TOTAL RECOVERABLE (UG/L AS CR) COPPER, TOTAL RECOVERABLE (UG/L AS CU) IRON, TOTAL RECOVERABLE (UG/L AS FE) LEAD, TOTAL RECOVERABLE (UG/L AS PB) LITHIUM, TOTAL RECOVERABLE (UG/L AS LI) MANGANESE, TOTAL RECOVERABLE (UG/L AS MN) MERCURY, TOTAL RECOVERABLE (UG/L AS HG) MOLYBDENUM, TOTAL RECOVERABLE (UG/L AS MO) NICKEL, TOTAL RECOVERABLE (UG/L AS NI ) SELENIUM, TOTAL RECOVERABLE (UG/L AS SE) ZINC, TOTAL RECOVERABLE (UG/L AS ZN)\nTABLt 14. SUMMARY OF WATER-QUALITY ANALYSES, MULE CREEK SITE D (07245594) [MG/L=MILLIGRAMS PER LITER, DEC C=DEGREES CELSIUS, PCI/L=PICOCURIES PER LITER, UMHO=MICROMHOS PER CENTIMETER AT 25 DEGREES CELSIUS, UG/L=MICROGRAMS PER LITER]',
#   'hashed_text': 'e7e52d39efdaeb31e2114d651b825119a83c05d4d07a4c0a3e19f2875538d5a8',
#   'cosmos_object_id': None,
#   'distance': -71.12478},
#  {'paper_id': '557ca80ae138239225f86935',
#   'preprocessor_id': 'haystack_v0.0.2',
#   'doc_type': 'paragraph',
#   'topic_list': ['criticalmaas'],
#   'text_content': 'ALUMINUM, DISSOLVED (UG/L AS AL ) ARSENIC, DISSOLVED (UG/L AS AS) BERYLLIUM, DISSOLVED (UG/L AS BE) CADMIUM, DISSOLVED (UG/L AS CD) CHROMIUM, DISSOLVED (UG/L AS CR ) COPPER, DISSOLVED (UG/L AS CU ) IRON, DISSOLVED (UG/L AS FE ) LEAD, DISSOLVED (UG/L AS PB) LITHIUM, DISSOLVED (UG/L AS LI) MANGANESE, DISSOLVED (UG/L AS MN ) MERCURY, DISSOLVED (UG/L AS HG ) MOLYBDENUM, DISSOLVED (UG/L AS MO) NICKEL, DISSOLVED (UG/L AS NI) SELENIUM, DISSOLVED (UG/L AS SE ) STRONTIUM, DISSOLVED (UG/L AS SR ) VANADIUM, DISSOLVED (UG/L AS V) ZINC, DISSOLVED (UG/L AS ZN )\nALUMINUM, TOTAL RECOVERABLE (UG/L AS AL ) ARSENIC, TOTAL RECOVERABLE (UG/L AS AS) BERYLLIUM, TOTAL RECOVERABLE (UG/L AS BE) CADMIUM TOTAL RECOVERABLE (UG/L AS CD) CHROMIUM, TOTAL RECOVERABLE (UG/L AS CR ) COPPER, TOTAL RECOVERABLE (UG/L AS CU ) IRON, TOTAL RECOVERABLE (UG/L AS FE) LEAD, TOTAL RECOVERABLE (UG/L AS PB) LITHIUM, TOTAL RECOVERABLE (UG/L AS LI) MANGANESE, TOTAL RECOVERABLE (UG/L AS MN ) MERCURY, TOTAL RECOVERABLE (UG/L AS HG ) MOLYBDENUM, TOTAL RECOVERABLE (UG/L AS MO) NICKEL, TOTAL RECOVERABLE (UG/L AS NI ) SELENIUM, TOTAL RECOVERABLE (UG/L AS SE ) ZINC, TOTAL RECOVERABLE (UG/L AS ZN )',
#   'hashed_text': '8dda22def4a00345809a9e726eed7bb1a80fbf0f8a5f782ab61f330812eb925c',
#   'cosmos_object_id': None,
#   'distance': -70.07955},
#  {'paper_id': '557a0f1fe138233a711e177c',
#   'preprocessor_id': 'haystack_v0.0.2',
#   'doc_type': 'paragraph',
#   'topic_list': ['criticalmaas'],
#   'text_content': 'Figure 16. Summary diagram of mass transfer of aluminum in mixing zones downstream from Mineral and Cement Creeks\nFigure 17. Summary diagram of mass transfer of iron in mixing zones downstream from Mineral and Cement Creeks\nFigure 18. Comparison of metal loads for aluminum, iron, zinc, cadmium, copper and lead at low flow (Oct., 1995) and high flow (May-June, 1996)\nFigure 28. Metal distribution profiles for Animas River: Silverton, Colo. to Aztec, New Mexico 74\nFigure 31. Downstream variation of the iron, aluminum, and copper to zinc ratios in colloids and bed sediments in the Animas River: Silverton to Aztec\nWater quality standards for metals, Colorado Lead-isotopic data from mineral deposits and mill sites, Silverton area Semi-quantitative emission spectrographic data from heavy-mineral separates,',
#   'hashed_text': '4019ef129649c053790c94c47c4b166377ac241d0023e3b7366ff67e68b77065',
#   'cosmos_object_id': None,
#   'distance': -69.38256},
#  {'paper_id': '55b70305e13823bd29ba7ecd',
#   'preprocessor_id': 'haystack_v0.0.2',
#   'doc_type': 'paragraph',
#   'topic_list': ['criticalmaas', 'dolomites'],
#   'text_content': '1. Map showing location of principal bauxite reserves and potential resources of the world__________________ In pocket\n2. Map showing location of bauxite districts and areas in southern United States ________________ ------ ___ In pocket\n2. Diagrams showing typical occurrences of bauxite________ 3. Generalized geologic map of the Arkansas bauxite district__ 4. Diagrammatic section showing principal types of deposits in the Arkansas bauxite district_____________________\n6. Northern South America_______________________ 7. Central and southern BraziL___________________ 8. Europe______________________________________ 9. West Africa__________________________________ 10. China (mainland)_____________________________ 11. India and West Pakistan_______________________\n13. Map showing location of potential sources of aluminum other than bauxite in the United States______________ 121\n2. United States imports of bauxite for consumption, by countries, 1950-64_ ___ __ ___ _____ _____ _____ _________',
#   'hashed_text': '64d6ef72da7a220ff1aa1c5500c500733a34749536e22828e92bf650d0119914',
#   'cosmos_object_id': None,
#   'distance': -68.708565},
#  {'paper_id': '558b16f9e13823109f3ed183',
#   'preprocessor_id': 'haystack_v0.0.2',
#   'doc_type': 'paragraph',
#   'topic_list': ['criticalmaas'],
#   'text_content': 'The uranium content of the sections is enriched by supergene processes at the base of the pseudowavellite-apatite zone (See (2) above*)\nHie origin of the surface sands and the source of the uranium are two major problems in the leached zone of the land pebble district* Field evidence indicates either a residual or depositional origin for the surface sands* In either case, the uranium in the leached zone could be a concentrated product of a once thicker section of slightly phosphatic 5 clayey quartz sand*\n2. Altschulerj, Z* S., Jaffe, E* B,, and Cuttitta, F«, The aluminum phosphate z.one of the Bone Valley formation and its uranium deposits (abstract): Contribution to the International Conference on Peaceful Uses of Atomic Energy, Geneva, Switzerland^, August 1955$ Session C,-p Role of Nuclear Energy 0 (in press)« /Rap No« l£ The Pliocene Bone Valley formation which contains most of the "Land Pebble" phosphates, occurs in west~central Florida east of the Tampa Bay region, unconformably overlying the lower and middle Miocene Hawthorn formation and covered by a surface mantle of quartz sands* It contains graded-bedded pebbly and clayey phosphatic sands in its lower two-thirds, which are mined, and a less phosphatic, massive-bedded, clayey sand, approximately 8 to',
#   'hashed_text': '90ad42b5ed7d696aea1d751b3f94f9197beb2f8a8b04cf80285194d528de7af8',
#   'cosmos_object_id': None,
#   'distance': -68.60281},
#  {'paper_id': '558e5cc3e13823109f3ee2df',
#   'preprocessor_id': 'haystack_v0.0.2',
#   'doc_type': 'paragraph',
#   'topic_list': ['criticalmaas', 'dolomites'],
#   'text_content': 'Other Geological Survey publications relating to the appraisal of resources of specific mineral commodities include the following:\nProfessional Paper 820 "United States Mineral Resources" Professional Paper 907 "Geology and Resources of Copper Deposits" Professional Paper 926 "Geology and Resources of Vanadium Deposits" Professional Paper 933 "Geology and Resources of Fluorine in the United States" Professional Paper 959 "Geology and Resources of Titanium in the United States"\nVeins _________________—— Replacements __________—————— Sedimentary deposits _______———— Alunite as an aluminum resource ____———— Pure alunite versus alunitic rock _——— Problems __________________ Acknowledgments __________________ Domestic resources ________________———— Utah __________________________ Marysvale district (Piute and Sevier Counties) Southern Wah Wah Mountains (Beaver and Iron Counties) ___________—————— Deposits in other areas ____________ Nevada ___________________————— Lincoln County _______________——— Clark County __________————————— Esmeralda County __—_______———— Mineral County _________________ Lyon County _______________———— Humboldt County ________________ Deposits in other areas ________—_— Arizona ____________________———_— Santa Cruz County ________________ Yuma County _______________—— Deposits in other areas ____________ Colorado _________________________ Hinsdale County _________________ Rio Grande County ________________ Custer County ___________________ Dolores County __________________ Deposits in other areas ______________ New Mexico __________________—___ Grant County ___________________ Sierra County ___________________ Luna County __________________ Deposits in other areas ______________ Washington __________________——__ California ________________________ Wyoming __________________———_____ Texas __________________________ Deposits in other States _______________ Minnesota _____________________ Arkansas ______________________ Kansas ______________________ Missouri _______________________ Indiana _______________________ South Dakota __________________ Pennsylvania ____________________ Alaska _______________________ Hawaii ________________________ Puerto Rico ______________________',
#   'hashed_text': '7fe543f3f8352380e9ed3f9e55890110e88b07c1fe1ba5d8939c924861d27280',
#   'cosmos_object_id': None,
#   'distance': -68.21669},
#  {'paper_id': '55b8fb22e13823bd29ba8b46',
#   'preprocessor_id': 'haystack_v0.0.2',
#   'doc_type': 'paragraph',
#   'topic_list': ['criticalmaas'],
#   'text_content': "U.S. Interagency Working Group on Industrial Ecology, Material and Energy Flow, 2000, Industrial ecology material and energy flows in the United States: U.S. Interagency Working Group or Industrial Ecology, Material and Energy Flow, 95 p.\nWhelpdale, D.M., 1992, An overview of the atmospheric sulphur cycle, in Howath, R.W., Stewart, J.W.B., and Ivanov, M.V., ec's., SCOPE\n48-Sulphur Cycling on the Continents-Wetlands, Terrestrial Ecosystems and Associated Water Bodies: New York, John Wiley and Sons, p. 5-26.\nWilburn, D.R., and Wagner, L.A., 1993, Aluminum availability and supply-A minerals availability appraisal: U.S. Bureau of Mines Information Circular 9371, 140 p.\nManuscript approved for publication December 5, 2001 Published in the USGS Central Region, Denver, Colorado Editing, layout, photocomposition-Richard W. Scott, Jr. Cover design, figures 2, 8-10, 14-Carol A. Quesenberry Figures 1, 3-7, 11-13-Springfield and Springfield",
#   'hashed_text': '6226e4335bedfa80833cf9326ee041adc011e14a7bb556c70b3cce90d3ac7c3c',
#   'cosmos_object_id': None,
#   'distance': -68.101776},
#  {'paper_id': '558b16f9e13823109f3ed183',
#   'preprocessor_id': 'haystack_v0.0.2',
#   'doc_type': 'paragraph',
#   'topic_list': ['criticalmaas'],
#   'text_content': 'The Canfield phosphate mine is about 2 miles west of Dover, Morris County, New Jersey* The ore is a granular aggregate of magnetite and greenish-gray apatite* with quartz* feldspar, and biotite the minor constituents« The mine was originally explored for magnetite, but the high apatite content of 35 percent made the ore worthless for smelting for iron, and the mine was abandoned* Among the rocks on the dump, those with the highest apatite content are also the most radioactive* Monazite is also present in small amounts and is radioactive*\nThe rocks of the Rutgers Mine, Clinton County, New York, and the Mulligan Quarry, Hunterdon County, New Jersey, also have some apatite, but the geology is described only briefly in this report*',
#   'hashed_text': 'f302796023a518b20b3732a14b1d6d787bedafcfd4a8fa20b8eaecc15cf78f75',
#   'cosmos_object_id': None,
#   'distance': -67.90485},
#  {'paper_id': '5d25161e0b45c76caf921719',
#   'preprocessor_id': 'haystack_v0.0.2',
#   'doc_type': 'paragraph',
#   'topic_list': ['criticalmaas'],
#   'text_content': 'Aluminum, dissolved (ug/L) Aluminum, bed material (pg/g) Iron, total (ug/L) Iron, dissolved (ug/L) Iron, bed material (ug/g) Manganese, total (ug/L)\nManganese, dissolved (ug/L) Manganese, bed material (pg/g) Nickel, dissolved (ug/L) Nickel, bed material (pg/g) Zinc, dissolved (pg/L) Zinc, bed material (pg/g)\nAlkalinity (mg/L as CaCOo) Sulfate, dissolved (mg/L) Dissolved solids (mg/L) Aluminum, total (pg/L) Aluminum, dissolved (pg/L) Aluminum, bed material (pg/g) Iron, total (pg/L) Iron, dissolved (pg/L)\nIron, bed material (pg/g) Manganese, total (pg/L) Manganese, dissolved (pg/L) Manganese, bed material (pg/g) Nickel f dissolved (jug/L) Nickel, bed material (pg/g) Zinc, dissolved (pg/L) Zinc, bed material (pg/g)\nTable 3. Summary of univariate statistics for observations grouped bv disturbance type in the Allegheny and Mononaahela Formations Continued',
#   'hashed_text': '9374f7d7034b21f40eae0eb09609e8994b019ac2a755c7b94087fb41fa3954cf',
#   'cosmos_object_id': None,
#   'distance': -67.59513},
#  {'paper_id': '5d505fea0b45c76cafa477a2',
#   'preprocessor_id': 'haystack_v0.0.2',
#   'doc_type': 'paragraph',
#   'topic_list': ['criticalmaas'],
#   'text_content': 'Aluminum, total Manganese, total recoverable dissolved recoverable (µg/L (µg/L (µg/L as Mn as Mn) as Al)\nAluminum, dissolved (µg/L as Al) -- -- -- -- -- -- -- -- -- -- -- -- -- --\nAluminum, total Manganese, total recoverable dissolved recoverable (µg/L (µg/L (µg/L as Mn as Mn) as Al)\nAluminum, dissolved (µg/L as Al) -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --\nAluminum, total Manganese, total recoverable dissolved recoverable (µg/L (µg/L (µg/L as Mn as Mn) as Al)\nAppendix 4. Prioritization index (PI) for all mine discharges [lb/d, pounds per day; gal/min, gallons per minute; <, less than] Appendix 4. Prioritization index (PI) for all mine discharges—Continued',
#   'hashed_text': 'f9fef1b9c80c921f5db06fe53446a2debcdb746d347350f280ac3dd605859bab',
#   'cosmos_object_id': None,
#   'distance': -67.06022}]

# %%
sample_text = response.json()[2]["text_content"]
sample_text
# Out:
# 'Figure 16. Summary diagram of mass transfer of aluminum in mixing zones downstream from Mineral and Cement Creeks\nFigure 17. Summary diagram of mass transfer of iron in mixing zones downstream from Mineral and Cement Creeks\nFigure 18. Comparison of metal loads for aluminum, iron, zinc, cadmium, copper and lead at low flow (Oct., 1995) and high flow (May-June, 1996)\nFigure 28. Metal distribution profiles for Animas River: Silverton, Colo. to Aztec, New Mexico 74\nFigure 31. Downstream variation of the iron, aluminum, and copper to zinc ratios in colloids and bed sediments in the Animas River: Silverton to Aztec\nWater quality standards for metals, Colorado Lead-isotopic data from mineral deposits and mill sites, Silverton area Semi-quantitative emission spectrographic data from heavy-mineral separates,'

# %% [markdown]
# ### Feed text to text2graph endpoint
#
# [docs](http://cosmos0002.chtc.wisc.edu:4503/docs)
#
# TODO: Improve documentation

# %% [markdown]
# #### GPT-4-turbo-preview

# %%
# TEXT2GRAPH_ENDPOINT = "http://cosmos0002.chtc.wisc.edu:4503/llm_graph"
TEXT2GRAPH_ENDPOINT = "http://localhost:4510/llm_graph"
TEXT2GRAPH_APIKEY = os.getenv("API_KEY")

headers = {"Content-Type": "application/json", "Api-Key": TEXT2GRAPH_APIKEY}
data = {"text": sample_text, "model": "gpt-4-turbo-preview", "prompt_version": "v0"}
response = requests.post(TEXT2GRAPH_ENDPOINT, headers=headers, json=data)

# %%
response.json()
# Out:
# {'Mineral and Cement Creeks': ['aluminum', 'iron'],
#  'Animas River': ['aluminum',
#   'iron',
#   'zinc',
#   'cadmium',
#   'copper',
#   'lead',
#   'colloids',
#   'bed sediments'],
#  'Silverton, Colo. to Aztec, New Mexico': ['metal distribution profiles'],
#  'Colorado': ['water quality standards for metals'],
#  'Silverton area': ['Lead-isotopic data',
#   'mineral deposits',
#   'mill sites',
#   'Semi-quantitative emission spectrographic data',
#   'heavy-mineral separates']}

# %% [markdown]
# #### Mixtral (Open source model)

# %%
data = {"text": sample_text, "model": "mixtral", "prompt_version": "v0"}
response = requests.post(TEXT2GRAPH_ENDPOINT, headers=headers, json=data)

# %%
response.json()
# Out:
# {'Mining and Cement Creeks': ['aluminum', 'iron'],
#  'Animas River: Silverton to Aztec': ['aluminum', 'iron', 'copper', 'zinc'],
#  'Silverton, Colo.': ['metals'],
#  'Colorado': ['water quality standards for metals'],
#  'Silverton area': ['Lead-isotopic data from mineral deposits and mill sites']}
